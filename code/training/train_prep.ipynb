# %%
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)
import os
import matplotlib.pyplot as plt
from src.sample_tiles import get_triplet_imgs, get_triplet_tiles, get_triplet_imgs_with_dirs

import sys
sys.path.append("..")
import torch
from torch import optim
from time import time

from src.datasets import TileTripletsDataset, GetBands, RandomFlipAndRotate, ClipAndScale, ToFloatTensor, triplet_dataloader
from src.tilenet import make_tilenet
from src.training import prep_triplets, train_triplet_epoch

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Prepare tiles

# %%
dir_of_img_dirs = '/storage/EuroSATallBands/'
img_dir_list = [x[0] for x in os.walk(dir_of_img_dirs)][1:]
print(img_dir_list)

tile_dir = '../data/triplets' # where you want to save your tiles
n_triplets = 500

# TODO - zmienic by brało obrazki tylko z train.csv
img_triplets = get_triplet_imgs_with_dirs(img_dir_list, n_triplets=n_triplets)
# print(img_triplets)

print(len(img_triplets))

tiles = get_triplet_tiles(tile_dir,
                        dir_of_img_dirs, 
                        img_triplets, 
                        tile_size=64,
                        val_type='float32',
                        bands_only=False,
                        save=True,
                        verbose=True)
# Out:
# ['/storage/EuroSATallBands/AnnualCrop', '/storage/EuroSATallBands/Highway', '/storage/EuroSATallBands/HerbaceousVegetation', '/storage/EuroSATallBands/Industrial', '/storage/EuroSATallBands/River', '/storage/EuroSATallBands/Pasture', '/storage/EuroSATallBands/Residential', '/storage/EuroSATallBands/PermanentCrop', '/storage/EuroSATallBands/Forest', '/storage/EuroSATallBands/SeaLake']
# 500
# Sampling image AnnualCrop/AnnualCrop_1012.tif from dir
#     Saving distant tile #17
#     Distant tile center:(50, 71)
# Sampling image AnnualCrop/AnnualCrop_1048.tif from dir
#     Saving anchor and neighbor tile #108
#     Anchor tile center:(56, 81)
#     Neighbor tile center:(53, 83)
# Sampling image AnnualCrop/AnnualCrop_1055.tif from dir
#     Saving distant tile #437
#     Distant tile center:(70, 41)
# Sampling image AnnualCrop/AnnualCrop_1072.tif from dir
#     Saving distant tile #32
#     Distant tile center:(42, 41)
# Sampling image AnnualCrop/AnnualCrop_1082.tif from dir
# /home/lukasz/.conda/envs/tile2vec/lib/python3.12/site-packages/osgeo/gdal.py:312: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
#     Saving distant tile #78
#     Distant tile center:(33, 67)
# Sampling image AnnualCrop/AnnualCrop_1123.tif from dir
#     Saving distant tile #260
#     Distant tile center:(43, 36)
# Sampling image AnnualCrop/AnnualCrop_1172.tif from dir
#     Saving anchor and neighbor tile #162
#     Anchor tile center:(35, 54)
#     Neighbor tile center:(95, 74)
# Sampling image AnnualCrop/AnnualCrop_1182.tif from dir
#     Saving anchor and neighbor tile #451
#     Anchor tile center:(67, 93)
#     Neighbor tile center:(48, 90)
# Sampling image AnnualCrop/AnnualCrop_1203.tif from dir
#     Saving anchor and neighbor tile #341
#     Anchor tile center:(69, 76)
#     Neighbor tile center:(56, 34)
# Sampling image AnnualCrop/AnnualCrop_1209.tif from dir
#     Saving distant tile #303
#     Distant tile center:(35, 72)
# Sampling image AnnualCrop/AnnualCrop_1219.tif from dir
#     Saving distant tile #83
#     Distant tile center:(93, 65)
# Sampling image AnnualCrop/AnnualCrop_1261.tif from dir
#     Saving distant tile #90
#     Distant tile center:(65, 92)
# Sampling image AnnualCrop/AnnualCrop_1289.tif from dir
#     Saving distant tile #480
#     Distant tile center:(90, 57)
# Sampling image AnnualCrop/AnnualCrop_1299.tif from dir
#     Saving anchor and neighbor tile #292
#     Anchor tile center:(40, 79)
#     Neighbor tile center:(64, 62)
# Sampling image AnnualCrop/AnnualCrop_1315.tif from dir
#     Saving distant tile #46
#     Distant tile center:(70, 52)
# Sampling image AnnualCrop/AnnualCrop_1339.tif from dir
#     Saving anchor and neighbor tile #499
#     Anchor tile center:(53, 84)
#     Neighbor tile center:(67, 32)
# Sampling image AnnualCrop/AnnualCrop_1348.tif from dir
#     Saving distant tile #468
#     Distant tile center:(79, 76)
# Sampling image AnnualCrop/AnnualCrop_1377.tif from dir
#     Saving anchor and neighbor tile #466
#     Anchor tile center:(52, 34)
#     Neighbor tile center:(94, 39)
# Sampling image AnnualCrop/AnnualCrop_1395.tif from dir
#     Saving distant tile #371
#     Distant tile center:(37, 59)
# Sampling image AnnualCrop/AnnualCrop_1404.tif from dir
#     Saving anchor and neighbor tile #305
#     Anchor tile center:(95, 73)
#     Neighbor tile center:(32, 52)
# Sampling image AnnualCrop/AnnualCrop_1414.tif from dir
#     Saving anchor and neighbor tile #315
#     Anchor tile center:(53, 69)
#     Neighbor tile center:(53, 73)
# Sampling image AnnualCrop/AnnualCrop_1438.tif from dir
#     Saving anchor and neighbor tile #303
#     Anchor tile center:(47, 94)
#     Neighbor tile center:(63, 67)
# Sampling image AnnualCrop/AnnualCrop_1472.tif from dir
#     Saving anchor and neighbor tile #63
#     Anchor tile center:(43, 32)
#     Neighbor tile center:(44, 80)
# Sampling image AnnualCrop/AnnualCrop_1482.tif from dir
#     Saving distant tile #451
#     Distant tile center:(84, 70)
# Sampling image AnnualCrop/AnnualCrop_1525.tif from dir
#     Saving distant tile #462
#     Distant tile center:(89, 94)
# Sampling image AnnualCrop/AnnualCrop_1546.tif from dir
#     Saving distant tile #200
#     Distant tile center:(74, 34)
# Sampling image AnnualCrop/AnnualCrop_1573.tif from dir
#     Saving anchor and neighbor tile #435
#     Anchor tile center:(62, 73)
#     Neighbor tile center:(62, 46)
# Sampling image AnnualCrop/AnnualCrop_1607.tif from dir
#     Saving anchor and neighbor tile #421
#     Anchor tile center:(85, 60)
#     Neighbor tile center:(50, 83)
# Sampling image AnnualCrop/AnnualCrop_1616.tif from dir
#     Saving anchor and neighbor tile #495
#     Anchor tile center:(35, 63)
#     Neighbor tile center:(89, 94)
# Sampling image AnnualCrop/AnnualCrop_1659.tif from dir
#     Saving anchor and neighbor tile #469
#     Anchor tile center:(33, 68)
#     Neighbor tile center:(78, 59)
# Sampling image AnnualCrop/AnnualCrop_1695.tif from dir
#     Saving anchor and neighbor tile #443
#     Anchor tile center:(35, 62)
#     Neighbor tile center:(85, 89)
# Sampling image AnnualCrop/AnnualCrop_1721.tif from dir
#     Saving distant tile #320
#     Distant tile center:(77, 85)
# Sampling image AnnualCrop/AnnualCrop_1729.tif from dir
#     Saving distant tile #302
#     Distant tile center:(37, 39)
# Sampling image AnnualCrop/AnnualCrop_1766.tif from dir
#     Saving anchor and neighbor tile #12
#     Anchor tile center:(57, 73)
#     Neighbor tile center:(48, 42)
# Sampling image AnnualCrop/AnnualCrop_1825.tif from dir
#     Saving distant tile #108
#     Distant tile center:(83, 90)
# Sampling image AnnualCrop/AnnualCrop_184.tif from dir
#     Saving anchor and neighbor tile #171
#     Anchor tile center:(33, 88)
#     Neighbor tile center:(82, 42)
# Sampling image AnnualCrop/AnnualCrop_1868.tif from dir
#     Saving anchor and neighbor tile #59
#     Anchor tile center:(57, 88)
#     Neighbor tile center:(78, 65)
# Sampling image AnnualCrop/AnnualCrop_1978.tif from dir
#     Saving anchor and neighbor tile #467
#     Anchor tile center:(78, 37)
#     Neighbor tile center:(68, 92)
# Sampling image AnnualCrop/AnnualCrop_1993.tif from dir
#     Saving distant tile #397
#     Distant tile center:(76, 54)
# Sampling image AnnualCrop/AnnualCrop_2002.tif from dir
#     Saving anchor and neighbor tile #277
#     Anchor tile center:(55, 92)
#     Neighbor tile center:(87, 32)
# Sampling image AnnualCrop/AnnualCrop_2005.tif from dir
#     Saving anchor and neighbor tile #41
#     Anchor tile center:(62, 83)
#     Neighbor tile center:(52, 87)
# Sampling image AnnualCrop/AnnualCrop_2007.tif from dir
#     Saving distant tile #143
#     Distant tile center:(91, 86)
# Sampling image AnnualCrop/AnnualCrop_2009.tif from dir
#     Saving distant tile #10
#     Distant tile center:(87, 34)
# Sampling image AnnualCrop/AnnualCrop_201.tif from dir
#     Saving anchor and neighbor tile #313
#     Anchor tile center:(58, 74)
#     Neighbor tile center:(75, 56)
# Sampling image AnnualCrop/AnnualCrop_2015.tif from dir
#     Saving distant tile #7
#     Distant tile center:(48, 82)
# Sampling image AnnualCrop/AnnualCrop_2054.tif from dir
#     Saving anchor and neighbor tile #72
#     Anchor tile center:(41, 71)
#     Neighbor tile center:(86, 66)
# Sampling image AnnualCrop/AnnualCrop_2083.tif from dir
#     Saving anchor and neighbor tile #471
#     Anchor tile center:(91, 83)
#     Neighbor tile center:(81, 70)
# Sampling image AnnualCrop/AnnualCrop_2135.tif from dir
#     Saving anchor and neighbor tile #325
#     Anchor tile center:(71, 48)
#     Neighbor tile center:(56, 88)
# Sampling image AnnualCrop/AnnualCrop_2162.tif from dir
#     Saving anchor and neighbor tile #77
#     Anchor tile center:(95, 66)
#     Neighbor tile center:(54, 73)
# Sampling image AnnualCrop/AnnualCrop_2167.tif from dir
#     Saving anchor and neighbor tile #192
#     Anchor tile center:(35, 69)
#     Neighbor tile center:(34, 54)
# Sampling image AnnualCrop/AnnualCrop_2168.tif from dir
#     Saving anchor and neighbor tile #406
#     Anchor tile center:(84, 70)
#     Neighbor tile center:(32, 51)
# Sampling image AnnualCrop/AnnualCrop_2176.tif from dir
#     Saving anchor and neighbor tile #324
#     Anchor tile center:(49, 62)
#     Neighbor tile center:(40, 53)
# Sampling image AnnualCrop/AnnualCrop_219.tif from dir
#     Saving distant tile #229
#     Distant tile center:(45, 89)
# Sampling image AnnualCrop/AnnualCrop_2222.tif from dir
#     Saving anchor and neighbor tile #273
#     Anchor tile center:(39, 61)
#     Neighbor tile center:(82, 39)
# Sampling image AnnualCrop/AnnualCrop_2227.tif from dir
#     Saving distant tile #2
#     Distant tile center:(76, 47)
# Sampling image AnnualCrop/AnnualCrop_2257.tif from dir
#     Saving anchor and neighbor tile #452
#     Anchor tile center:(87, 48)
#     Neighbor tile center:(67, 45)
# Sampling image AnnualCrop/AnnualCrop_2276.tif from dir
#     Saving anchor and neighbor tile #73
#     Anchor tile center:(70, 92)
#     Neighbor tile center:(69, 72)
# Sampling image AnnualCrop/AnnualCrop_2299.tif from dir
#     Saving anchor and neighbor tile #134
#     Anchor tile center:(36, 55)
#     Neighbor tile center:(32, 69)
# Sampling image AnnualCrop/AnnualCrop_232.tif from dir
#     Saving anchor and neighbor tile #489
#     Anchor tile center:(90, 39)
#     Neighbor tile center:(32, 77)
# Sampling image AnnualCrop/AnnualCrop_2335.tif from dir
#     Saving anchor and neighbor tile #40
#     Anchor tile center:(58, 71)
#     Neighbor tile center:(69, 50)
# Sampling image AnnualCrop/AnnualCrop_2337.tif from dir
#     Saving distant tile #56
#     Distant tile center:(89, 88)
# Sampling image AnnualCrop/AnnualCrop_2431.tif from dir
#     Saving anchor and neighbor tile #176
#     Anchor tile center:(63, 36)
#     Neighbor tile center:(63, 95)
# Sampling image AnnualCrop/AnnualCrop_2465.tif from dir
#     Saving anchor and neighbor tile #216
#     Anchor tile center:(78, 49)
#     Neighbor tile center:(94, 43)
# Sampling image AnnualCrop/AnnualCrop_2488.tif from dir
#     Saving distant tile #178
#     Distant tile center:(65, 83)
# Sampling image AnnualCrop/AnnualCrop_2492.tif from dir
#     Saving anchor and neighbor tile #80
#     Anchor tile center:(85, 60)
#     Neighbor tile center:(48, 43)
# Sampling image AnnualCrop/AnnualCrop_2519.tif from dir
#     Saving distant tile #130
#     Distant tile center:(94, 46)
# Sampling image AnnualCrop/AnnualCrop_2552.tif from dir
#     Saving distant tile #109
#     Distant tile center:(47, 41)
#     Saving distant tile #439
#     Distant tile center:(36, 86)
# Sampling image AnnualCrop/AnnualCrop_2556.tif from dir
#     Saving distant tile #37
#     Distant tile center:(35, 33)
# Sampling image AnnualCrop/AnnualCrop_2558.tif from dir
#     Saving distant tile #267
#     Distant tile center:(69, 54)
# Sampling image AnnualCrop/AnnualCrop_2602.tif from dir
#     Saving anchor and neighbor tile #493
#     Anchor tile center:(46, 91)
#     Neighbor tile center:(65, 58)
# Sampling image AnnualCrop/AnnualCrop_2646.tif from dir
#     Saving distant tile #381
#     Distant tile center:(88, 54)
# Sampling image AnnualCrop/AnnualCrop_2698.tif from dir
#     Saving distant tile #112
#     Distant tile center:(95, 60)
#     Saving anchor and neighbor tile #234
#     Anchor tile center:(80, 59)
#     Neighbor tile center:(93, 36)
# Sampling image AnnualCrop/AnnualCrop_2703.tif from dir
#     Saving anchor and neighbor tile #175
#     Anchor tile center:(75, 53)
#     Neighbor tile center:(83, 61)
# Sampling image AnnualCrop/AnnualCrop_2706.tif from dir
#     Saving distant tile #351
#     Distant tile center:(81, 50)
# Sampling image AnnualCrop/AnnualCrop_2727.tif from dir
#     Saving distant tile #201
#     Distant tile center:(55, 37)
# Sampling image AnnualCrop/AnnualCrop_276.tif from dir
#     Saving anchor and neighbor tile #178
#     Anchor tile center:(61, 46)
#     Neighbor tile center:(40, 66)
# Sampling image AnnualCrop/AnnualCrop_2792.tif from dir
#     Saving anchor and neighbor tile #264
#     Anchor tile center:(70, 91)
#     Neighbor tile center:(68, 68)
# Sampling image AnnualCrop/AnnualCrop_2794.tif from dir
#     Saving anchor and neighbor tile #372
#     Anchor tile center:(34, 46)
#     Neighbor tile center:(95, 67)
# Sampling image AnnualCrop/AnnualCrop_2800.tif from dir
#     Saving anchor and neighbor tile #267
#     Anchor tile center:(61, 76)
#     Neighbor tile center:(91, 78)
# Sampling image AnnualCrop/AnnualCrop_2808.tif from dir
#     Saving anchor and neighbor tile #30
#     Anchor tile center:(68, 94)
#     Neighbor tile center:(36, 78)
# Sampling image AnnualCrop/AnnualCrop_2817.tif from dir
#     Saving anchor and neighbor tile #135
#     Anchor tile center:(32, 83)
#     Neighbor tile center:(38, 59)
# Sampling image AnnualCrop/AnnualCrop_2829.tif from dir
#     Saving distant tile #368
#     Distant tile center:(32, 46)
# Sampling image AnnualCrop/AnnualCrop_2831.tif from dir
#     Saving distant tile #215
#     Distant tile center:(44, 47)
# Sampling image AnnualCrop/AnnualCrop_2849.tif from dir
#     Saving distant tile #153
#     Distant tile center:(53, 51)
# Sampling image AnnualCrop/AnnualCrop_2857.tif from dir
#     Saving anchor and neighbor tile #393
#     Anchor tile center:(77, 76)
#     Neighbor tile center:(63, 55)
# Sampling image AnnualCrop/AnnualCrop_2951.tif from dir
#     Saving anchor and neighbor tile #317
#     Anchor tile center:(57, 95)
#     Neighbor tile center:(86, 44)
# Sampling image AnnualCrop/AnnualCrop_2974.tif from dir
#     Saving anchor and neighbor tile #322
#     Anchor tile center:(59, 74)
#     Neighbor tile center:(37, 50)
# Sampling image AnnualCrop/AnnualCrop_318.tif from dir
#     Saving distant tile #4
#     Distant tile center:(88, 51)
# Sampling image AnnualCrop/AnnualCrop_332.tif from dir
#     Saving distant tile #433
#     Distant tile center:(81, 49)
# Sampling image AnnualCrop/AnnualCrop_336.tif from dir
#     Saving anchor and neighbor tile #311
#     Anchor tile center:(46, 76)
#     Neighbor tile center:(34, 61)
# Sampling image AnnualCrop/AnnualCrop_342.tif from dir
#     Saving anchor and neighbor tile #269
#     Anchor tile center:(56, 71)
#     Neighbor tile center:(72, 78)
# Sampling image AnnualCrop/AnnualCrop_358.tif from dir
#     Saving distant tile #394
#     Distant tile center:(90, 60)
# Sampling image AnnualCrop/AnnualCrop_365.tif from dir
#     Saving distant tile #380
#     Distant tile center:(64, 43)
# Sampling image AnnualCrop/AnnualCrop_378.tif from dir
#     Saving anchor and neighbor tile #257
#     Anchor tile center:(91, 41)
#     Neighbor tile center:(87, 85)
#     Saving anchor and neighbor tile #448
#     Anchor tile center:(32, 36)
#     Neighbor tile center:(93, 58)
# Sampling image AnnualCrop/AnnualCrop_394.tif from dir
#     Saving distant tile #156
#     Distant tile center:(46, 46)
# Sampling image AnnualCrop/AnnualCrop_417.tif from dir
#     Saving anchor and neighbor tile #212
#     Anchor tile center:(93, 93)
#     Neighbor tile center:(59, 72)
# Sampling image AnnualCrop/AnnualCrop_453.tif from dir
#     Saving anchor and neighbor tile #113
#     Anchor tile center:(89, 40)
#     Neighbor tile center:(56, 78)
# Sampling image AnnualCrop/AnnualCrop_47.tif from dir
#     Saving anchor and neighbor tile #215
#     Anchor tile center:(45, 39)
#     Neighbor tile center:(35, 65)
# Sampling image AnnualCrop/AnnualCrop_472.tif from dir
#     Saving anchor and neighbor tile #172
#     Anchor tile center:(67, 92)
#     Neighbor tile center:(43, 43)
# Sampling image AnnualCrop/AnnualCrop_479.tif from dir
#     Saving anchor and neighbor tile #65
#     Anchor tile center:(69, 34)
#     Neighbor tile center:(88, 83)
# Sampling image AnnualCrop/AnnualCrop_508.tif from dir
#     Saving anchor and neighbor tile #461
#     Anchor tile center:(77, 83)
#     Neighbor tile center:(93, 71)
# Sampling image AnnualCrop/AnnualCrop_524.tif from dir
#     Saving distant tile #248
#     Distant tile center:(56, 71)
# Sampling image AnnualCrop/AnnualCrop_527.tif from dir
#     Saving anchor and neighbor tile #444
#     Anchor tile center:(33, 91)
#     Neighbor tile center:(44, 76)
# Sampling image AnnualCrop/AnnualCrop_567.tif from dir
#     Saving distant tile #115
#     Distant tile center:(84, 94)
# Sampling image AnnualCrop/AnnualCrop_568.tif from dir
#     Saving anchor and neighbor tile #18
#     Anchor tile center:(81, 74)
#     Neighbor tile center:(67, 58)
# Sampling image AnnualCrop/AnnualCrop_609.tif from dir
#     Saving anchor and neighbor tile #366
#     Anchor tile center:(34, 48)
#     Neighbor tile center:(41, 87)
# Sampling image AnnualCrop/AnnualCrop_702.tif from dir
#     Saving anchor and neighbor tile #300
#     Anchor tile center:(55, 66)
#     Neighbor tile center:(39, 58)
# Sampling image AnnualCrop/AnnualCrop_76.tif from dir
#     Saving anchor and neighbor tile #222
#     Anchor tile center:(44, 61)
#     Neighbor tile center:(58, 62)
# Sampling image AnnualCrop/AnnualCrop_779.tif from dir
#     Saving anchor and neighbor tile #340
#     Anchor tile center:(86, 42)
#     Neighbor tile center:(50, 32)
# Sampling image AnnualCrop/AnnualCrop_791.tif from dir
#     Saving anchor and neighbor tile #235
#     Anchor tile center:(56, 33)
#     Neighbor tile center:(39, 35)
# Sampling image AnnualCrop/AnnualCrop_794.tif from dir
#     Saving distant tile #238
#     Distant tile center:(62, 50)
# Sampling image AnnualCrop/AnnualCrop_807.tif from dir
#     Saving anchor and neighbor tile #161
#     Anchor tile center:(51, 83)
#     Neighbor tile center:(76, 63)
# Sampling image AnnualCrop/AnnualCrop_868.tif from dir
#     Saving distant tile #95
#     Distant tile center:(68, 93)
#     Saving anchor and neighbor tile #136
#     Anchor tile center:(35, 65)
#     Neighbor tile center:(42, 73)
# Sampling image AnnualCrop/AnnualCrop_991.tif from dir
#     Saving distant tile #199
#     Distant tile center:(51, 67)
# Sampling image AnnualCrop/AnnualCrop_996.tif from dir
#     Saving anchor and neighbor tile #16
#     Anchor tile center:(60, 66)
#     Neighbor tile center:(43, 57)
#     Saving distant tile #329
#     Distant tile center:(44, 77)
# Sampling image Forest/Forest_1008.tif from dir
#     Saving distant tile #74
#     Distant tile center:(72, 38)
# Sampling image Forest/Forest_1048.tif from dir
#     Saving distant tile #410
#     Distant tile center:(42, 49)
# Sampling image Forest/Forest_1087.tif from dir
#     Saving distant tile #286
#     Distant tile center:(49, 61)
# Sampling image Forest/Forest_1164.tif from dir
#     Saving distant tile #440
#     Distant tile center:(35, 94)
# Sampling image Forest/Forest_1197.tif from dir
#     Saving anchor and neighbor tile #245
#     Anchor tile center:(67, 56)
#     Neighbor tile center:(70, 90)
# Sampling image Forest/Forest_1217.tif from dir
#     Saving distant tile #223
#     Distant tile center:(36, 45)
# Sampling image Forest/Forest_1242.tif from dir
#     Saving anchor and neighbor tile #91
#     Anchor tile center:(48, 47)
#     Neighbor tile center:(77, 89)
# Sampling image Forest/Forest_1258.tif from dir
#     Saving anchor and neighbor tile #312
#     Anchor tile center:(71, 83)
#     Neighbor tile center:(32, 35)
# Sampling image Forest/Forest_1275.tif from dir
#     Saving anchor and neighbor tile #417
#     Anchor tile center:(91, 64)
#     Neighbor tile center:(37, 50)
# Sampling image Forest/Forest_1313.tif from dir
#     Saving anchor and neighbor tile #319
#     Anchor tile center:(59, 87)
#     Neighbor tile center:(35, 63)
# Sampling image Forest/Forest_132.tif from dir
#     Saving distant tile #287
#     Distant tile center:(53, 86)
# Sampling image Forest/Forest_1326.tif from dir
#     Saving anchor and neighbor tile #440
#     Anchor tile center:(35, 81)
#     Neighbor tile center:(87, 54)
# Sampling image Forest/Forest_1361.tif from dir
#     Saving anchor and neighbor tile #60
#     Anchor tile center:(37, 53)
#     Neighbor tile center:(80, 69)
# Sampling image Forest/Forest_1376.tif from dir
#     Saving distant tile #5
#     Distant tile center:(45, 72)
# Sampling image Forest/Forest_1391.tif from dir
#     Saving anchor and neighbor tile #285
#     Anchor tile center:(73, 62)
#     Neighbor tile center:(71, 46)
# Sampling image Forest/Forest_1399.tif from dir
#     Saving distant tile #358
#     Distant tile center:(62, 70)
# Sampling image Forest/Forest_1421.tif from dir
#     Saving distant tile #66
#     Distant tile center:(93, 78)
# Sampling image Forest/Forest_1431.tif from dir
#     Saving distant tile #69
#     Distant tile center:(41, 86)
# Sampling image Forest/Forest_1454.tif from dir
#     Saving distant tile #49
#     Distant tile center:(82, 46)
# Sampling image Forest/Forest_1468.tif from dir
#     Saving distant tile #191
#     Distant tile center:(46, 37)
# Sampling image Forest/Forest_1476.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(50, 54)
#     Neighbor tile center:(76, 55)
# Sampling image Forest/Forest_1519.tif from dir
#     Saving anchor and neighbor tile #182
#     Anchor tile center:(55, 39)
#     Neighbor tile center:(75, 89)
# Sampling image Forest/Forest_1530.tif from dir
#     Saving distant tile #312
#     Distant tile center:(60, 34)
# Sampling image Forest/Forest_1572.tif from dir
#     Saving distant tile #264
#     Distant tile center:(34, 84)
# Sampling image Forest/Forest_1579.tif from dir
#     Saving distant tile #235
#     Distant tile center:(60, 49)
# Sampling image Forest/Forest_1584.tif from dir
#     Saving anchor and neighbor tile #290
#     Anchor tile center:(88, 35)
#     Neighbor tile center:(73, 61)
# Sampling image Forest/Forest_1588.tif from dir
#     Saving distant tile #345
#     Distant tile center:(42, 46)
# Sampling image Forest/Forest_1596.tif from dir
#     Saving distant tile #484
#     Distant tile center:(35, 71)
# Sampling image Forest/Forest_1643.tif from dir
#     Saving anchor and neighbor tile #256
#     Anchor tile center:(39, 40)
#     Neighbor tile center:(60, 95)
# Sampling image Forest/Forest_1694.tif from dir
#     Saving distant tile #340
#     Distant tile center:(42, 86)
# Sampling image Forest/Forest_171.tif from dir
#     Saving anchor and neighbor tile #42
#     Anchor tile center:(83, 75)
#     Neighbor tile center:(68, 48)
# Sampling image Forest/Forest_1742.tif from dir
#     Saving distant tile #463
#     Distant tile center:(70, 35)
# Sampling image Forest/Forest_1768.tif from dir
#     Saving anchor and neighbor tile #309
#     Anchor tile center:(95, 38)
#     Neighbor tile center:(93, 77)
# Sampling image Forest/Forest_1791.tif from dir
#     Saving distant tile #184
#     Distant tile center:(80, 89)
# Sampling image Forest/Forest_1800.tif from dir
#     Saving anchor and neighbor tile #280
#     Anchor tile center:(73, 58)
#     Neighbor tile center:(94, 90)
# Sampling image Forest/Forest_1811.tif from dir
#     Saving anchor and neighbor tile #445
#     Anchor tile center:(67, 42)
#     Neighbor tile center:(94, 59)
# Sampling image Forest/Forest_1812.tif from dir
#     Saving distant tile #68
#     Distant tile center:(45, 36)
# Sampling image Forest/Forest_1822.tif from dir
#     Saving anchor and neighbor tile #97
#     Anchor tile center:(50, 34)
#     Neighbor tile center:(65, 93)
# Sampling image Forest/Forest_1824.tif from dir
#     Saving distant tile #490
#     Distant tile center:(93, 81)
# Sampling image Forest/Forest_1830.tif from dir
#     Saving distant tile #383
#     Distant tile center:(68, 73)
# Sampling image Forest/Forest_1849.tif from dir
#     Saving distant tile #489
#     Distant tile center:(43, 54)
# Sampling image Forest/Forest_1865.tif from dir
#     Saving anchor and neighbor tile #227
#     Anchor tile center:(79, 65)
#     Neighbor tile center:(90, 77)
# Sampling image Forest/Forest_1885.tif from dir
#     Saving distant tile #47
#     Distant tile center:(55, 58)
# Sampling image Forest/Forest_1909.tif from dir
#     Saving distant tile #338
#     Distant tile center:(38, 33)
# Sampling image Forest/Forest_1938.tif from dir
#     Saving anchor and neighbor tile #120
#     Anchor tile center:(54, 71)
#     Neighbor tile center:(81, 55)
# Sampling image Forest/Forest_198.tif from dir
#     Saving anchor and neighbor tile #410
#     Anchor tile center:(62, 32)
#     Neighbor tile center:(56, 56)
# Sampling image Forest/Forest_1981.tif from dir
#     Saving anchor and neighbor tile #331
#     Anchor tile center:(67, 43)
#     Neighbor tile center:(55, 68)
# Sampling image Forest/Forest_2036.tif from dir
#     Saving anchor and neighbor tile #194
#     Anchor tile center:(56, 57)
#     Neighbor tile center:(41, 88)
# Sampling image Forest/Forest_2048.tif from dir
#     Saving anchor and neighbor tile #376
#     Anchor tile center:(70, 35)
#     Neighbor tile center:(72, 51)
# Sampling image Forest/Forest_2062.tif from dir
#     Saving distant tile #417
#     Distant tile center:(86, 91)
# Sampling image Forest/Forest_2080.tif from dir
#     Saving distant tile #297
#     Distant tile center:(47, 86)
# Sampling image Forest/Forest_2095.tif from dir
#     Saving anchor and neighbor tile #407
#     Anchor tile center:(88, 53)
#     Neighbor tile center:(48, 57)
# Sampling image Forest/Forest_2096.tif from dir
#     Saving anchor and neighbor tile #153
#     Anchor tile center:(35, 85)
#     Neighbor tile center:(77, 90)
# Sampling image Forest/Forest_2122.tif from dir
#     Saving anchor and neighbor tile #361
#     Anchor tile center:(51, 53)
#     Neighbor tile center:(75, 77)
# Sampling image Forest/Forest_2129.tif from dir
#     Saving anchor and neighbor tile #249
#     Anchor tile center:(78, 89)
#     Neighbor tile center:(59, 55)
# Sampling image Forest/Forest_224.tif from dir
#     Saving anchor and neighbor tile #459
#     Anchor tile center:(37, 95)
#     Neighbor tile center:(87, 40)
# Sampling image Forest/Forest_225.tif from dir
#     Saving distant tile #467
#     Distant tile center:(51, 74)
# Sampling image Forest/Forest_2273.tif from dir
#     Saving distant tile #352
#     Distant tile center:(36, 77)
# Sampling image Forest/Forest_2308.tif from dir
#     Saving anchor and neighbor tile #296
#     Anchor tile center:(77, 66)
#     Neighbor tile center:(45, 50)
# Sampling image Forest/Forest_2331.tif from dir
#     Saving distant tile #469
#     Distant tile center:(36, 66)
# Sampling image Forest/Forest_2358.tif from dir
#     Saving distant tile #326
#     Distant tile center:(62, 35)
# Sampling image Forest/Forest_2359.tif from dir
#     Saving distant tile #160
#     Distant tile center:(93, 53)
# Sampling image Forest/Forest_236.tif from dir
#     Saving anchor and neighbor tile #463
#     Anchor tile center:(73, 91)
#     Neighbor tile center:(40, 82)
# Sampling image Forest/Forest_2415.tif from dir
#     Saving anchor and neighbor tile #307
#     Anchor tile center:(67, 68)
#     Neighbor tile center:(63, 62)
# Sampling image Forest/Forest_243.tif from dir
#     Saving distant tile #406
#     Distant tile center:(83, 53)
# Sampling image Forest/Forest_2430.tif from dir
#     Saving anchor and neighbor tile #243
#     Anchor tile center:(61, 88)
#     Neighbor tile center:(57, 57)
# Sampling image Forest/Forest_2530.tif from dir
#     Saving distant tile #486
#     Distant tile center:(63, 39)
# Sampling image Forest/Forest_2537.tif from dir
#     Saving anchor and neighbor tile #219
#     Anchor tile center:(58, 32)
#     Neighbor tile center:(55, 92)
# Sampling image Forest/Forest_2541.tif from dir
#     Saving distant tile #478
#     Distant tile center:(93, 92)
# Sampling image Forest/Forest_2547.tif from dir
#     Saving distant tile #379
#     Distant tile center:(88, 56)
# Sampling image Forest/Forest_2588.tif from dir
#     Saving anchor and neighbor tile #333
#     Anchor tile center:(63, 90)
#     Neighbor tile center:(37, 61)
# Sampling image Forest/Forest_2597.tif from dir
#     Saving anchor and neighbor tile #143
#     Anchor tile center:(41, 34)
#     Neighbor tile center:(87, 48)
# Sampling image Forest/Forest_2637.tif from dir
#     Saving distant tile #222
#     Distant tile center:(94, 59)
#     Saving distant tile #459
#     Distant tile center:(65, 82)
# Sampling image Forest/Forest_2661.tif from dir
#     Saving distant tile #276
#     Distant tile center:(32, 52)
# Sampling image Forest/Forest_2673.tif from dir
#     Saving anchor and neighbor tile #33
#     Anchor tile center:(84, 58)
#     Neighbor tile center:(50, 36)
# Sampling image Forest/Forest_2712.tif from dir
#     Saving distant tile #487
#     Distant tile center:(45, 38)
# Sampling image Forest/Forest_2714.tif from dir
#     Saving distant tile #124
#     Distant tile center:(71, 56)
# Sampling image Forest/Forest_2728.tif from dir
#     Saving distant tile #425
#     Distant tile center:(52, 85)
# Sampling image Forest/Forest_278.tif from dir
#     Saving anchor and neighbor tile #50
#     Anchor tile center:(85, 58)
#     Neighbor tile center:(67, 32)
#     Saving anchor and neighbor tile #76
#     Anchor tile center:(74, 74)
#     Neighbor tile center:(32, 58)
# Sampling image Forest/Forest_2790.tif from dir
#     Saving distant tile #378
#     Distant tile center:(60, 81)
# Sampling image Forest/Forest_2794.tif from dir
#     Saving anchor and neighbor tile #209
#     Anchor tile center:(44, 68)
#     Neighbor tile center:(80, 43)
# Sampling image Forest/Forest_2797.tif from dir
#     Saving distant tile #271
#     Distant tile center:(93, 72)
# Sampling image Forest/Forest_2805.tif from dir
#     Saving distant tile #62
#     Distant tile center:(91, 48)
# Sampling image Forest/Forest_281.tif from dir
#     Saving distant tile #255
#     Distant tile center:(70, 83)
# Sampling image Forest/Forest_2855.tif from dir
#     Saving anchor and neighbor tile #278
#     Anchor tile center:(46, 47)
#     Neighbor tile center:(64, 44)
# Sampling image Forest/Forest_2872.tif from dir
#     Saving anchor and neighbor tile #334
#     Anchor tile center:(70, 42)
#     Neighbor tile center:(93, 66)
# Sampling image Forest/Forest_2879.tif from dir
#     Saving anchor and neighbor tile #465
#     Anchor tile center:(64, 46)
#     Neighbor tile center:(47, 42)
# Sampling image Forest/Forest_2894.tif from dir
#     Saving anchor and neighbor tile #53
#     Anchor tile center:(57, 65)
#     Neighbor tile center:(92, 39)
# Sampling image Forest/Forest_2909.tif from dir
#     Saving anchor and neighbor tile #274
#     Anchor tile center:(79, 42)
#     Neighbor tile center:(89, 41)
# Sampling image Forest/Forest_2956.tif from dir
#     Saving distant tile #319
#     Distant tile center:(95, 60)
# Sampling image Forest/Forest_312.tif from dir
#     Saving distant tile #311
#     Distant tile center:(95, 41)
# Sampling image Forest/Forest_378.tif from dir
#     Saving distant tile #466
#     Distant tile center:(65, 32)
# Sampling image Forest/Forest_486.tif from dir
#     Saving distant tile #243
#     Distant tile center:(71, 46)
# Sampling image Forest/Forest_492.tif from dir
#     Saving anchor and neighbor tile #438
#     Anchor tile center:(32, 47)
#     Neighbor tile center:(93, 62)
# Sampling image Forest/Forest_5.tif from dir
#     Saving anchor and neighbor tile #179
#     Anchor tile center:(42, 38)
#     Neighbor tile center:(57, 38)
# Sampling image Forest/Forest_501.tif from dir
#     Saving distant tile #148
#     Distant tile center:(55, 57)
# Sampling image Forest/Forest_579.tif from dir
#     Saving anchor and neighbor tile #314
#     Anchor tile center:(73, 32)
#     Neighbor tile center:(59, 34)
# Sampling image Forest/Forest_607.tif from dir
#     Saving anchor and neighbor tile #258
#     Anchor tile center:(80, 49)
#     Neighbor tile center:(89, 54)
# Sampling image Forest/Forest_620.tif from dir
#     Saving distant tile #59
#     Distant tile center:(89, 41)
# Sampling image Forest/Forest_623.tif from dir
#     Saving anchor and neighbor tile #414
#     Anchor tile center:(52, 60)
#     Neighbor tile center:(59, 90)
# Sampling image Forest/Forest_658.tif from dir
#     Saving distant tile #497
#     Distant tile center:(64, 83)
# Sampling image Forest/Forest_713.tif from dir
#     Saving anchor and neighbor tile #122
#     Anchor tile center:(70, 86)
#     Neighbor tile center:(80, 85)
# Sampling image Forest/Forest_739.tif from dir
#     Saving distant tile #168
#     Distant tile center:(67, 85)
# Sampling image Forest/Forest_742.tif from dir
#     Saving distant tile #461
#     Distant tile center:(89, 67)
# Sampling image Forest/Forest_759.tif from dir
#     Saving distant tile #452
#     Distant tile center:(35, 83)
# Sampling image Forest/Forest_786.tif from dir
#     Saving anchor and neighbor tile #81
#     Anchor tile center:(75, 52)
#     Neighbor tile center:(93, 39)
# Sampling image Forest/Forest_8.tif from dir
#     Saving distant tile #355
#     Distant tile center:(38, 54)
# Sampling image Forest/Forest_801.tif from dir
#     Saving anchor and neighbor tile #368
#     Anchor tile center:(54, 56)
#     Neighbor tile center:(32, 59)
# Sampling image Forest/Forest_803.tif from dir
#     Saving distant tile #129
#     Distant tile center:(88, 82)
# Sampling image Forest/Forest_835.tif from dir
#     Saving anchor and neighbor tile #301
#     Anchor tile center:(45, 81)
#     Neighbor tile center:(59, 49)
# Sampling image Forest/Forest_908.tif from dir
#     Saving anchor and neighbor tile #47
#     Anchor tile center:(88, 58)
#     Neighbor tile center:(91, 87)
# Sampling image Forest/Forest_916.tif from dir
#     Saving distant tile #142
#     Distant tile center:(59, 80)
# Sampling image Forest/Forest_934.tif from dir
#     Saving distant tile #214
#     Distant tile center:(88, 80)
# Sampling image Forest/Forest_95.tif from dir
#     Saving distant tile #389
#     Distant tile center:(95, 77)
# Sampling image Forest/Forest_951.tif from dir
#     Saving anchor and neighbor tile #82
#     Anchor tile center:(50, 56)
#     Neighbor tile center:(76, 75)
# Sampling image Forest/Forest_987.tif from dir
#     Saving distant tile #268
#     Distant tile center:(68, 61)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_102.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(57, 70)
#     Neighbor tile center:(70, 45)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1039.tif from dir
#     Saving anchor and neighbor tile #349
#     Anchor tile center:(80, 43)
#     Neighbor tile center:(76, 33)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1048.tif from dir
#     Saving anchor and neighbor tile #164
#     Anchor tile center:(65, 47)
#     Neighbor tile center:(47, 48)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1098.tif from dir
#     Saving distant tile #390
#     Distant tile center:(67, 56)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1099.tif from dir
#     Saving distant tile #349
#     Distant tile center:(76, 70)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1109.tif from dir
#     Saving distant tile #239
#     Distant tile center:(53, 87)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1134.tif from dir
#     Saving anchor and neighbor tile #35
#     Anchor tile center:(82, 86)
#     Neighbor tile center:(35, 73)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1142.tif from dir
#     Saving anchor and neighbor tile #247
#     Anchor tile center:(86, 58)
#     Neighbor tile center:(78, 61)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1152.tif from dir
#     Saving distant tile #290
#     Distant tile center:(52, 32)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1154.tif from dir
#     Saving distant tile #34
#     Distant tile center:(36, 82)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1170.tif from dir
#     Saving distant tile #1
#     Distant tile center:(89, 92)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1179.tif from dir
#     Saving distant tile #117
#     Distant tile center:(55, 36)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1192.tif from dir
#     Saving distant tile #274
#     Distant tile center:(78, 85)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1216.tif from dir
#     Saving distant tile #240
#     Distant tile center:(66, 74)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1240.tif from dir
#     Saving distant tile #227
#     Distant tile center:(74, 41)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1247.tif from dir
#     Saving anchor and neighbor tile #431
#     Anchor tile center:(48, 71)
#     Neighbor tile center:(34, 66)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1252.tif from dir
#     Saving anchor and neighbor tile #106
#     Anchor tile center:(90, 85)
#     Neighbor tile center:(95, 81)
#     Saving anchor and neighbor tile #396
#     Anchor tile center:(60, 80)
#     Neighbor tile center:(86, 63)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1283.tif from dir
#     Saving anchor and neighbor tile #125
#     Anchor tile center:(72, 35)
#     Neighbor tile center:(43, 84)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1413.tif from dir
#     Saving anchor and neighbor tile #260
#     Anchor tile center:(61, 38)
#     Neighbor tile center:(77, 32)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1430.tif from dir
#     Saving distant tile #266
#     Distant tile center:(93, 41)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_15.tif from dir
#     Saving distant tile #472
#     Distant tile center:(50, 77)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1509.tif from dir
#     Saving anchor and neighbor tile #66
#     Anchor tile center:(66, 55)
#     Neighbor tile center:(46, 69)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_151.tif from dir
#     Saving distant tile #67
#     Distant tile center:(72, 94)
#     Saving anchor and neighbor tile #148
#     Anchor tile center:(34, 45)
#     Neighbor tile center:(78, 48)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1535.tif from dir
#     Saving distant tile #230
#     Distant tile center:(86, 43)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1570.tif from dir
#     Saving distant tile #236
#     Distant tile center:(34, 70)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1585.tif from dir
#     Saving distant tile #105
#     Distant tile center:(44, 45)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1588.tif from dir
#     Saving anchor and neighbor tile #199
#     Anchor tile center:(38, 87)
#     Neighbor tile center:(89, 71)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1595.tif from dir
#     Saving distant tile #133
#     Distant tile center:(74, 93)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1617.tif from dir
#     Saving anchor and neighbor tile #92
#     Anchor tile center:(66, 68)
#     Neighbor tile center:(65, 67)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1669.tif from dir
#     Saving distant tile #416
#     Distant tile center:(84, 67)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1674.tif from dir
#     Saving anchor and neighbor tile #189
#     Anchor tile center:(72, 45)
#     Neighbor tile center:(54, 55)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1685.tif from dir
#     Saving distant tile #8
#     Distant tile center:(39, 32)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1693.tif from dir
#     Saving distant tile #180
#     Distant tile center:(34, 53)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1715.tif from dir
#     Saving distant tile #151
#     Distant tile center:(62, 41)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1717.tif from dir
#     Saving anchor and neighbor tile #486
#     Anchor tile center:(82, 88)
#     Neighbor tile center:(90, 49)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_173.tif from dir
#     Saving anchor and neighbor tile #476
#     Anchor tile center:(81, 65)
#     Neighbor tile center:(83, 55)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1733.tif from dir
#     Saving distant tile #449
#     Distant tile center:(88, 82)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1767.tif from dir
#     Saving anchor and neighbor tile #115
#     Anchor tile center:(67, 66)
#     Neighbor tile center:(42, 81)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1811.tif from dir
#     Saving distant tile #97
#     Distant tile center:(92, 66)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_183.tif from dir
#     Saving distant tile #328
#     Distant tile center:(48, 73)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1864.tif from dir
#     Saving anchor and neighbor tile #177
#     Anchor tile center:(84, 48)
#     Neighbor tile center:(90, 75)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_187.tif from dir
#     Saving distant tile #194
#     Distant tile center:(77, 94)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1880.tif from dir
#     Saving distant tile #85
#     Distant tile center:(38, 87)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1883.tif from dir
#     Saving anchor and neighbor tile #228
#     Anchor tile center:(47, 90)
#     Neighbor tile center:(33, 33)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_1937.tif from dir
#     Saving anchor and neighbor tile #221
#     Anchor tile center:(39, 83)
#     Neighbor tile center:(80, 35)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2005.tif from dir
#     Saving distant tile #183
#     Distant tile center:(67, 95)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_203.tif from dir
#     Saving anchor and neighbor tile #166
#     Anchor tile center:(71, 95)
#     Neighbor tile center:(87, 54)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2039.tif from dir
#     Saving distant tile #192
#     Distant tile center:(95, 94)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2051.tif from dir
#     Saving anchor and neighbor tile #370
#     Anchor tile center:(85, 78)
#     Neighbor tile center:(38, 90)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_206.tif from dir
#     Saving distant tile #189
#     Distant tile center:(38, 71)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2107.tif from dir
#     Saving distant tile #498
#     Distant tile center:(32, 68)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2113.tif from dir
#     Saving distant tile #277
#     Distant tile center:(63, 70)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2163.tif from dir
#     Saving anchor and neighbor tile #265
#     Anchor tile center:(79, 79)
#     Neighbor tile center:(83, 61)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2212.tif from dir
#     Saving distant tile #210
#     Distant tile center:(87, 47)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2217.tif from dir
#     Saving anchor and neighbor tile #259
#     Anchor tile center:(51, 73)
#     Neighbor tile center:(95, 89)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2277.tif from dir
#     Saving anchor and neighbor tile #230
#     Anchor tile center:(70, 78)
#     Neighbor tile center:(40, 76)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2283.tif from dir
#     Saving anchor and neighbor tile #262
#     Anchor tile center:(42, 55)
#     Neighbor tile center:(94, 92)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_229.tif from dir
#     Saving distant tile #405
#     Distant tile center:(65, 82)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2312.tif from dir
#     Saving anchor and neighbor tile #484
#     Anchor tile center:(77, 57)
#     Neighbor tile center:(64, 59)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2362.tif from dir
#     Saving distant tile #205
#     Distant tile center:(46, 79)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2396.tif from dir
#     Saving distant tile #270
#     Distant tile center:(88, 67)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2437.tif from dir
#     Saving distant tile #225
#     Distant tile center:(91, 58)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2438.tif from dir
#     Saving distant tile #418
#     Distant tile center:(73, 79)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2488.tif from dir
#     Saving anchor and neighbor tile #193
#     Anchor tile center:(92, 81)
#     Neighbor tile center:(68, 46)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2503.tif from dir
#     Saving anchor and neighbor tile #58
#     Anchor tile center:(46, 47)
#     Neighbor tile center:(86, 50)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2514.tif from dir
#     Saving anchor and neighbor tile #462
#     Anchor tile center:(93, 37)
#     Neighbor tile center:(54, 60)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2541.tif from dir
#     Saving distant tile #233
#     Distant tile center:(38, 32)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2631.tif from dir
#     Saving anchor and neighbor tile #487
#     Anchor tile center:(44, 41)
#     Neighbor tile center:(36, 38)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2666.tif from dir
#     Saving anchor and neighbor tile #231
#     Anchor tile center:(45, 44)
#     Neighbor tile center:(83, 72)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2694.tif from dir
#     Saving anchor and neighbor tile #275
#     Anchor tile center:(53, 86)
#     Neighbor tile center:(39, 49)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2698.tif from dir
#     Saving anchor and neighbor tile #32
#     Anchor tile center:(39, 51)
#     Neighbor tile center:(77, 47)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2745.tif from dir
#     Saving anchor and neighbor tile #266
#     Anchor tile center:(83, 35)
#     Neighbor tile center:(72, 44)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2756.tif from dir
#     Saving distant tile #363
#     Distant tile center:(65, 47)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2773.tif from dir
#     Saving distant tile #399
#     Distant tile center:(90, 93)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2785.tif from dir
#     Saving anchor and neighbor tile #478
#     Anchor tile center:(76, 58)
#     Neighbor tile center:(52, 32)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2845.tif from dir
#     Saving distant tile #190
#     Distant tile center:(54, 72)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2862.tif from dir
#     Saving distant tile #296
#     Distant tile center:(78, 77)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2870.tif from dir
#     Saving distant tile #482
#     Distant tile center:(40, 61)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_29.tif from dir
#     Saving distant tile #423
#     Distant tile center:(61, 39)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_2966.tif from dir
#     Saving distant tile #125
#     Distant tile center:(74, 53)
#     Saving anchor and neighbor tile #363
#     Anchor tile center:(41, 32)
#     Neighbor tile center:(34, 81)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_305.tif from dir
#     Saving anchor and neighbor tile #202
#     Anchor tile center:(62, 95)
#     Neighbor tile center:(40, 44)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_310.tif from dir
#     Saving distant tile #465
#     Distant tile center:(59, 87)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_329.tif from dir
#     Saving anchor and neighbor tile #127
#     Anchor tile center:(41, 92)
#     Neighbor tile center:(70, 44)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_483.tif from dir
#     Saving distant tile #197
#     Distant tile center:(67, 63)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_514.tif from dir
#     Saving distant tile #481
#     Distant tile center:(73, 33)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_526.tif from dir
#     Saving anchor and neighbor tile #352
#     Anchor tile center:(57, 79)
#     Neighbor tile center:(40, 48)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_549.tif from dir
#     Saving distant tile #288
#     Distant tile center:(75, 53)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_564.tif from dir
#     Saving distant tile #48
#     Distant tile center:(67, 92)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_566.tif from dir
#     Saving anchor and neighbor tile #21
#     Anchor tile center:(50, 56)
#     Neighbor tile center:(93, 73)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_568.tif from dir
#     Saving distant tile #179
#     Distant tile center:(40, 86)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_57.tif from dir
#     Saving distant tile #375
#     Distant tile center:(50, 61)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_577.tif from dir
#     Saving distant tile #50
#     Distant tile center:(36, 86)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_631.tif from dir
#     Saving anchor and neighbor tile #353
#     Anchor tile center:(68, 87)
#     Neighbor tile center:(81, 68)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_636.tif from dir
#     Saving distant tile #61
#     Distant tile center:(43, 44)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_65.tif from dir
#     Saving distant tile #186
#     Distant tile center:(61, 50)
# Sampling image HerbaceousVegetation/HerbaceousVegetation_683.tif from dir
#     Saving anchor and neighbor tile #412
#     Anchor tile center:(49, 92)
#     Neighbor tile center:(71, 68)
# ...
#     Saving anchor and neighbor tile #133
#     Anchor tile center:(43, 35)
#     Neighbor tile center:(48, 85)
# Sampling image SeaLake/Jakarta_000405.tif from dir
#     Saving anchor and neighbor tile #306
#     Anchor tile center:(46, 93)
#     Neighbor tile center:(47, 38)
# Sampling image SeaLake/Jakarta_000417.tif from dir
#     Saving anchor and neighbor tile #54
#     Anchor tile center:(60, 32)
#     Neighbor tile center:(70, 39)
# Sampling image SeaLake/Jakarta_000421.tif from dir
#     Saving anchor and neighbor tile #389
#     Anchor tile center:(58, 53)
#     Neighbor tile center:(87, 61)
# Sampling image SeaLake/Jakarta_000438.tif from dir
#     Saving anchor and neighbor tile #210
#     Anchor tile center:(89, 34)
#     Neighbor tile center:(62, 91)
# Sampling image SeaLake/Jakarta_000470.tif from dir
#     Saving anchor and neighbor tile #392
#     Anchor tile center:(60, 69)
#     Neighbor tile center:(60, 46)
# Sampling image SeaLake/Jakarta_000471.tif from dir
#     Saving anchor and neighbor tile #23
#     Anchor tile center:(52, 57)
#     Neighbor tile center:(70, 77)
# Sampling image SeaLake/Jakarta_000490.tif from dir
#     Saving distant tile #38
#     Distant tile center:(71, 86)
# Sampling image SeaLake/Jakarta_000498.tif from dir
#     Saving anchor and neighbor tile #94
#     Anchor tile center:(37, 95)
#     Neighbor tile center:(80, 45)
# Sampling image SeaLake/SeaLake_1007.tif from dir
#     Saving distant tile #228
#     Distant tile center:(50, 77)
# Sampling image SeaLake/SeaLake_1039.tif from dir
#     Saving anchor and neighbor tile #93
#     Anchor tile center:(68, 51)
#     Neighbor tile center:(88, 91)
# Sampling image SeaLake/SeaLake_1046.tif from dir
#     Saving anchor and neighbor tile #483
#     Anchor tile center:(87, 70)
#     Neighbor tile center:(89, 54)
# Sampling image SeaLake/SeaLake_1071.tif from dir
#     Saving anchor and neighbor tile #128
#     Anchor tile center:(74, 80)
#     Neighbor tile center:(78, 95)
# Sampling image SeaLake/SeaLake_1100.tif from dir
#     Saving distant tile #259
#     Distant tile center:(81, 61)
# Sampling image SeaLake/SeaLake_1138.tif from dir
#     Saving distant tile #226
#     Distant tile center:(72, 61)
# Sampling image SeaLake/SeaLake_1155.tif from dir
#     Saving anchor and neighbor tile #271
#     Anchor tile center:(82, 42)
#     Neighbor tile center:(75, 63)
# Sampling image SeaLake/SeaLake_1168.tif from dir
#     Saving distant tile #33
#     Distant tile center:(57, 57)
# Sampling image SeaLake/SeaLake_117.tif from dir
#     Saving anchor and neighbor tile #373
#     Anchor tile center:(95, 38)
#     Neighbor tile center:(38, 41)
# Sampling image SeaLake/SeaLake_1212.tif from dir
#     Saving anchor and neighbor tile #118
#     Anchor tile center:(81, 64)
#     Neighbor tile center:(48, 54)
# Sampling image SeaLake/SeaLake_1227.tif from dir
#     Saving anchor and neighbor tile #25
#     Anchor tile center:(90, 35)
#     Neighbor tile center:(45, 50)
# Sampling image SeaLake/SeaLake_1308.tif from dir
#     Saving anchor and neighbor tile #31
#     Anchor tile center:(81, 75)
#     Neighbor tile center:(79, 78)
# Sampling image SeaLake/SeaLake_1315.tif from dir
#     Saving anchor and neighbor tile #398
#     Anchor tile center:(80, 77)
#     Neighbor tile center:(63, 68)
# Sampling image SeaLake/SeaLake_1319.tif from dir
#     Saving anchor and neighbor tile #51
#     Anchor tile center:(36, 37)
#     Neighbor tile center:(33, 81)
# Sampling image SeaLake/SeaLake_1346.tif from dir
#     Saving distant tile #122
#     Distant tile center:(49, 37)
# Sampling image SeaLake/SeaLake_1358.tif from dir
#     Saving anchor and neighbor tile #390
#     Anchor tile center:(61, 61)
#     Neighbor tile center:(65, 68)
# Sampling image SeaLake/SeaLake_140.tif from dir
#     Saving anchor and neighbor tile #401
#     Anchor tile center:(43, 53)
#     Neighbor tile center:(86, 41)
# Sampling image SeaLake/SeaLake_1430.tif from dir
#     Saving anchor and neighbor tile #100
#     Anchor tile center:(88, 37)
#     Neighbor tile center:(79, 43)
# Sampling image SeaLake/SeaLake_1436.tif from dir
#     Saving anchor and neighbor tile #79
#     Anchor tile center:(71, 87)
#     Neighbor tile center:(45, 36)
# Sampling image SeaLake/SeaLake_1443.tif from dir
#     Saving distant tile #175
#     Distant tile center:(56, 40)
# Sampling image SeaLake/SeaLake_1571.tif from dir
#     Saving anchor and neighbor tile #402
#     Anchor tile center:(41, 36)
#     Neighbor tile center:(94, 88)
# Sampling image SeaLake/SeaLake_1615.tif from dir
#     Saving distant tile #169
#     Distant tile center:(48, 93)
# Sampling image SeaLake/SeaLake_1644.tif from dir
#     Saving distant tile #141
#     Distant tile center:(46, 65)
# Sampling image SeaLake/SeaLake_172.tif from dir
#     Saving anchor and neighbor tile #383
#     Anchor tile center:(79, 47)
#     Neighbor tile center:(57, 77)
# Sampling image SeaLake/SeaLake_177.tif from dir
#     Saving anchor and neighbor tile #168
#     Anchor tile center:(72, 39)
#     Neighbor tile center:(45, 71)
# Sampling image SeaLake/SeaLake_1803.tif from dir
#     Saving distant tile #426
#     Distant tile center:(67, 49)
# Sampling image SeaLake/SeaLake_1870.tif from dir
#     Saving distant tile #254
#     Distant tile center:(65, 32)
# Sampling image SeaLake/SeaLake_1897.tif from dir
#     Saving anchor and neighbor tile #447
#     Anchor tile center:(32, 66)
#     Neighbor tile center:(90, 72)
# Sampling image SeaLake/SeaLake_1899.tif from dir
#     Saving distant tile #415
#     Distant tile center:(40, 79)
# Sampling image SeaLake/SeaLake_1917.tif from dir
#     Saving distant tile #291
#     Distant tile center:(91, 34)
# Sampling image SeaLake/SeaLake_1928.tif from dir
#     Saving anchor and neighbor tile #400
#     Anchor tile center:(92, 38)
#     Neighbor tile center:(34, 82)
# Sampling image SeaLake/SeaLake_1987.tif from dir
#     Saving anchor and neighbor tile #449
#     Anchor tile center:(80, 56)
#     Neighbor tile center:(64, 70)
# Sampling image SeaLake/SeaLake_2076.tif from dir
#     Saving anchor and neighbor tile #96
#     Anchor tile center:(78, 45)
#     Neighbor tile center:(49, 62)
# Sampling image SeaLake/SeaLake_2120.tif from dir
#     Saving anchor and neighbor tile #460
#     Anchor tile center:(61, 92)
#     Neighbor tile center:(60, 40)
# Sampling image SeaLake/SeaLake_2155.tif from dir
#     Saving anchor and neighbor tile #205
#     Anchor tile center:(82, 51)
#     Neighbor tile center:(41, 60)
# Sampling image SeaLake/SeaLake_2163.tif from dir
#     Saving anchor and neighbor tile #321
#     Anchor tile center:(49, 92)
#     Neighbor tile center:(84, 65)
# Sampling image SeaLake/SeaLake_2191.tif from dir
#     Saving distant tile #252
#     Distant tile center:(46, 46)
# Sampling image SeaLake/SeaLake_2202.tif from dir
#     Saving distant tile #24
#     Distant tile center:(46, 67)
# Sampling image SeaLake/SeaLake_2209.tif from dir
#     Saving distant tile #93
#     Distant tile center:(94, 85)
# Sampling image SeaLake/SeaLake_2247.tif from dir
#     Saving anchor and neighbor tile #151
#     Anchor tile center:(85, 35)
#     Neighbor tile center:(43, 81)
# Sampling image SeaLake/SeaLake_2264.tif from dir
#     Saving anchor and neighbor tile #386
#     Anchor tile center:(50, 49)
#     Neighbor tile center:(79, 57)
# Sampling image SeaLake/SeaLake_229.tif from dir
#     Saving distant tile #293
#     Distant tile center:(52, 34)
# Sampling image SeaLake/SeaLake_2326.tif from dir
#     Saving distant tile #0
#     Distant tile center:(60, 54)
# Sampling image SeaLake/SeaLake_2364.tif from dir
#     Saving distant tile #119
#     Distant tile center:(68, 81)
# Sampling image SeaLake/SeaLake_239.tif from dir
#     Saving distant tile #181
#     Distant tile center:(86, 65)
# Sampling image SeaLake/SeaLake_2398.tif from dir
#     Saving distant tile #382
#     Distant tile center:(68, 63)
# Sampling image SeaLake/SeaLake_2431.tif from dir
#     Saving anchor and neighbor tile #477
#     Anchor tile center:(77, 71)
#     Neighbor tile center:(93, 62)
# Sampling image SeaLake/SeaLake_2455.tif from dir
#     Saving anchor and neighbor tile #188
#     Anchor tile center:(47, 89)
#     Neighbor tile center:(74, 76)
# Sampling image SeaLake/SeaLake_2457.tif from dir
#     Saving distant tile #150
#     Distant tile center:(82, 88)
# Sampling image SeaLake/SeaLake_2462.tif from dir
#     Saving anchor and neighbor tile #485
#     Anchor tile center:(37, 69)
#     Neighbor tile center:(40, 61)
# Sampling image SeaLake/SeaLake_2496.tif from dir
#     Saving distant tile #113
#     Distant tile center:(34, 56)
# Sampling image SeaLake/SeaLake_2587.tif from dir
#     Saving anchor and neighbor tile #48
#     Anchor tile center:(62, 53)
#     Neighbor tile center:(66, 48)
# Sampling image SeaLake/SeaLake_2602.tif from dir
#     Saving anchor and neighbor tile #343
#     Anchor tile center:(74, 47)
#     Neighbor tile center:(89, 90)
# Sampling image SeaLake/SeaLake_262.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(48, 65)
#     Neighbor tile center:(75, 80)
# Sampling image SeaLake/SeaLake_2632.tif from dir
#     Saving anchor and neighbor tile #283
#     Anchor tile center:(42, 71)
#     Neighbor tile center:(70, 61)
# Sampling image SeaLake/SeaLake_2673.tif from dir
#     Saving anchor and neighbor tile #195
#     Anchor tile center:(73, 55)
#     Neighbor tile center:(34, 82)
# Sampling image SeaLake/SeaLake_2683.tif from dir
#     Saving anchor and neighbor tile #299
#     Anchor tile center:(83, 92)
#     Neighbor tile center:(52, 70)
# Sampling image SeaLake/SeaLake_2704.tif from dir
#     Saving anchor and neighbor tile #492
#     Anchor tile center:(77, 57)
#     Neighbor tile center:(59, 36)
# Sampling image SeaLake/SeaLake_2710.tif from dir
#     Saving distant tile #31
#     Distant tile center:(34, 70)
# Sampling image SeaLake/SeaLake_2719.tif from dir
#     Saving distant tile #123
#     Distant tile center:(72, 92)
# Sampling image SeaLake/SeaLake_2720.tif from dir
#     Saving distant tile #458
#     Distant tile center:(76, 59)
# Sampling image SeaLake/SeaLake_2727.tif from dir
#     Saving distant tile #325
#     Distant tile center:(51, 79)
# Sampling image SeaLake/SeaLake_2728.tif from dir
#     Saving anchor and neighbor tile #339
#     Anchor tile center:(88, 40)
#     Neighbor tile center:(62, 58)
# Sampling image SeaLake/SeaLake_273.tif from dir
#     Saving distant tile #414
#     Distant tile center:(56, 89)
# Sampling image SeaLake/SeaLake_2784.tif from dir
#     Saving anchor and neighbor tile #248
#     Anchor tile center:(87, 51)
#     Neighbor tile center:(90, 56)
# Sampling image SeaLake/SeaLake_2804.tif from dir
#     Saving anchor and neighbor tile #496
#     Anchor tile center:(47, 88)
#     Neighbor tile center:(95, 87)
# Sampling image SeaLake/SeaLake_2822.tif from dir
#     Saving anchor and neighbor tile #437
#     Anchor tile center:(36, 87)
#     Neighbor tile center:(81, 32)
# Sampling image SeaLake/SeaLake_2866.tif from dir
#     Saving anchor and neighbor tile #214
#     Anchor tile center:(69, 92)
#     Neighbor tile center:(59, 57)
# Sampling image SeaLake/SeaLake_2877.tif from dir
#     Saving anchor and neighbor tile #236
#     Anchor tile center:(75, 49)
#     Neighbor tile center:(48, 83)
# Sampling image SeaLake/SeaLake_2907.tif from dir
#     Saving distant tile #82
#     Distant tile center:(91, 53)
#     Saving anchor and neighbor tile #429
#     Anchor tile center:(74, 39)
#     Neighbor tile center:(45, 88)
# Sampling image SeaLake/SeaLake_2943.tif from dir
#     Saving distant tile #249
#     Distant tile center:(62, 56)
# Sampling image SeaLake/SeaLake_2965.tif from dir
#     Saving distant tile #322
#     Distant tile center:(49, 82)
#     Saving anchor and neighbor tile #439
#     Anchor tile center:(68, 85)
#     Neighbor tile center:(76, 76)
# Sampling image SeaLake/SeaLake_2969.tif from dir
#     Saving distant tile #335
#     Distant tile center:(69, 95)
# Sampling image SeaLake/SeaLake_2980.tif from dir
#     Saving anchor and neighbor tile #279
#     Anchor tile center:(90, 37)
#     Neighbor tile center:(87, 83)
# Sampling image SeaLake/SeaLake_300.tif from dir
#     Saving distant tile #187
#     Distant tile center:(52, 57)
# Sampling image SeaLake/SeaLake_302.tif from dir
#     Saving anchor and neighbor tile #11
#     Anchor tile center:(39, 77)
#     Neighbor tile center:(50, 70)
# Sampling image SeaLake/SeaLake_342.tif from dir
#     Saving distant tile #104
#     Distant tile center:(50, 53)
# Sampling image SeaLake/SeaLake_345.tif from dir
#     Saving distant tile #162
#     Distant tile center:(33, 33)
# Sampling image SeaLake/SeaLake_352.tif from dir
#     Saving anchor and neighbor tile #38
#     Anchor tile center:(90, 91)
#     Neighbor tile center:(60, 55)
# Sampling image SeaLake/SeaLake_395.tif from dir
#     Saving anchor and neighbor tile #342
#     Anchor tile center:(62, 61)
#     Neighbor tile center:(46, 83)
# Sampling image SeaLake/SeaLake_431.tif from dir
#     Saving anchor and neighbor tile #385
#     Anchor tile center:(32, 94)
#     Neighbor tile center:(83, 35)
# Sampling image SeaLake/SeaLake_472.tif from dir
#     Saving anchor and neighbor tile #287
#     Anchor tile center:(38, 68)
#     Neighbor tile center:(52, 89)
# Sampling image SeaLake/SeaLake_48.tif from dir
#     Saving distant tile #400
#     Distant tile center:(45, 39)
# Sampling image SeaLake/SeaLake_500.tif from dir
#     Saving anchor and neighbor tile #473
#     Anchor tile center:(34, 52)
#     Neighbor tile center:(74, 86)
# Sampling image SeaLake/SeaLake_561.tif from dir
#     Saving distant tile #324
#     Distant tile center:(52, 81)
# Sampling image SeaLake/SeaLake_579.tif from dir
#     Saving distant tile #367
#     Distant tile center:(80, 95)
# Sampling image SeaLake/SeaLake_614.tif from dir
#     Saving anchor and neighbor tile #39
#     Anchor tile center:(84, 40)
#     Neighbor tile center:(94, 83)
# Sampling image SeaLake/SeaLake_629.tif from dir
#     Saving distant tile #247
#     Distant tile center:(55, 91)
# Sampling image SeaLake/SeaLake_642.tif from dir
#     Saving anchor and neighbor tile #22
#     Anchor tile center:(86, 59)
#     Neighbor tile center:(87, 44)
#     Saving distant tile #26
#     Distant tile center:(32, 33)
# Sampling image SeaLake/SeaLake_646.tif from dir
#     Saving anchor and neighbor tile #145
#     Anchor tile center:(61, 66)
#     Neighbor tile center:(50, 57)
# Sampling image SeaLake/SeaLake_697.tif from dir
#     Saving distant tile #373
#     Distant tile center:(35, 87)
# Sampling image SeaLake/SeaLake_717.tif from dir
#     Saving distant tile #114
#     Distant tile center:(56, 75)
# Sampling image SeaLake/SeaLake_756.tif from dir
#     Saving anchor and neighbor tile #482
#     Anchor tile center:(78, 85)
#     Neighbor tile center:(49, 92)
# Sampling image SeaLake/SeaLake_757.tif from dir
#     Saving anchor and neighbor tile #304
#     Anchor tile center:(52, 38)
#     Neighbor tile center:(52, 58)
# Sampling image SeaLake/SeaLake_784.tif from dir
#     Saving distant tile #331
#     Distant tile center:(48, 52)
# Sampling image SeaLake/SeaLake_803.tif from dir
#     Saving distant tile #216
#     Distant tile center:(60, 81)
# Sampling image SeaLake/SeaLake_815.tif from dir
#     Saving distant tile #182
#     Distant tile center:(91, 45)
# Sampling image SeaLake/SeaLake_824.tif from dir
#     Saving anchor and neighbor tile #71
#     Anchor tile center:(59, 85)
#     Neighbor tile center:(85, 47)
# Sampling image SeaLake/SeaLake_830.tif from dir
#     Saving distant tile #221
#     Distant tile center:(86, 92)
# Sampling image SeaLake/SeaLake_832.tif from dir
#     Saving distant tile #232
#     Distant tile center:(94, 39)
# Sampling image SeaLake/SeaLake_875.tif from dir
#     Saving distant tile #155
#     Distant tile center:(76, 87)
# Sampling image SeaLake/SeaLake_932.tif from dir
#     Saving anchor and neighbor tile #441
#     Anchor tile center:(85, 69)
#     Neighbor tile center:(43, 59)
# Sampling image SeaLake/SeaLake_940.tif from dir
#     Saving anchor and neighbor tile #28
#     Anchor tile center:(77, 53)
#     Neighbor tile center:(56, 89)
# Sampling image SeaLake/SeaLake_957.tif from dir
#     Saving distant tile #19
#     Distant tile center:(94, 88)
# Sampling image SeaLake/SeaLake_979.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(77, 80)
#     Neighbor tile center:(91, 91)
# Sampling image SeaLake/SeaLake_984.tif from dir
#     Saving anchor and neighbor tile #323
#     Anchor tile center:(72, 58)
#     Neighbor tile center:(79, 45)

# %% [markdown]
# # Train

# %% [markdown]
# ## Setup data

# %%
# Environment stuff
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
cuda = torch.cuda.is_available()

# Change these arguments to match your directory and desired parameters
img_type = 'naip'
# tile_dir = '../data/triplets/'
bands = 12
augment = True
batch_size = 50
shuffle = True
num_workers = 4
# n_triplets = 10 # trzeba ustawić na tyle ile jest w data/triplets

dataloader = triplet_dataloader(img_type, tile_dir, bands=bands, augment=augment,
                                batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, 
                                n_triplets=n_triplets, pairs_only=True)
print('Dataloader set up complete.')
# Out:
# Dataloader set up complete.

# %% [markdown]
# ## Setup tilenet

# %%
in_channels = bands
z_dim = 512

TileNet = make_tilenet(in_channels=in_channels, z_dim=z_dim)
TileNet.train()
if cuda: TileNet.cuda()
print('TileNet set up complete.')

lr = 1e-3
optimizer = optim.Adam(TileNet.parameters(), lr=lr, betas=(0.5, 0.999))
# Out:
# TileNet set up complete.

# %% [markdown]
# # Train model

# %%
epochs = 50
margin = 10
l2 = 0.01
print_every = 10000
save_models = True

model_dir = '../models/'
if not os.path.exists(model_dir): os.makedirs(model_dir)

results_fn = 'result_fn'

t0 = time()
with open(results_fn, 'w') as file:

    print('Begin training.................')
    for epoch in range(0, epochs):
        (avg_loss, avg_l_n, avg_l_d, avg_l_nd) = train_triplet_epoch(
            TileNet, cuda, dataloader, optimizer, epoch+1, margin=margin, l2=l2,
            print_every=print_every, t0=t0)

# Save model after last epoch
if save_models:
    model_fn = os.path.join(model_dir, 'TileNet_epoch50.ckpt')
    torch.save(TileNet.state_dict(), model_fn)
# Out:
# Begin training.................
# self.tile_dir: ../data/triplets/234anchor.npy
# self.tile_dir: ../data/triplets/249anchor.npy
#
#
# self.tile_dir: ../data/triplets/76anchor.npy
#
# self.tile_dir: ../data/triplets/56anchor.npy
#
# self.tile_dir: ../data/triplets/333anchor.npy
#
# self.tile_dir: ../data/triplets/464anchor.npy
#
# self.tile_dir: ../data/triplets/210anchor.npy
#
# self.tile_dir: ../data/triplets/479anchor.npy
# self.tile_dir: ../data/triplets/330anchor.npy
#
#
# self.tile_dir: ../data/triplets/66anchor.npy
#
# self.tile_dir: ../data/triplets/6anchor.npy
# self.tile_dir: ../data/triplets/289anchor.npy
#
#
# self.tile_dir: ../data/triplets/327anchor.npy
# self.tile_dir: ../data/triplets/392anchor.npy
#
#
# self.tile_dir: ../data/triplets/423anchor.npy
# self.tile_dir: ../data/triplets/118anchor.npy
# self.tile_dir: ../data/triplets/412anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/4anchor.npy
#
# self.tile_dir: ../data/triplets/150anchor.npy
# self.tile_dir: ../data/triplets/280anchor.npy
#
#
# self.tile_dir: ../data/triplets/238anchor.npy
#
# self.tile_dir: ../data/triplets/293anchor.npy
# self.tile_dir: ../data/triplets/445anchor.npy
#
#
# self.tile_dir: ../data/triplets/458anchor.npy
#
# self.tile_dir: ../data/triplets/326anchor.npy
# self.tile_dir: ../data/triplets/496anchor.npy
#
#
# self.tile_dir: ../data/triplets/88anchor.npy
#
# self.tile_dir: ../data/triplets/173anchor.npy
#
# self.tile_dir: ../data/triplets/158anchor.npy
# self.tile_dir: ../data/triplets/355anchor.npy
#
#
# self.tile_dir: ../data/triplets/207anchor.npy
#
# self.tile_dir: ../data/triplets/393anchor.npy
# self.tile_dir: ../data/triplets/132anchor.npy
#
#
# self.tile_dir: ../data/triplets/473anchor.npy
#
# self.tile_dir: ../data/triplets/124anchor.npy
# self.tile_dir: ../data/triplets/461anchor.npy
#
#
# self.tile_dir: ../data/triplets/194anchor.npy
#
# self.tile_dir: ../data/triplets/344anchor.npy
# self.tile_dir: ../data/triplets/360anchor.npy
#
#
# self.tile_dir: ../data/triplets/101anchor.npy
#
# self.tile_dir: ../data/triplets/340anchor.npy
# self.tile_dir: ../data/triplets/46anchor.npy
#
#
# self.tile_dir: ../data/triplets/471anchor.npy
#
# self.tile_dir: ../data/triplets/245anchor.npy
# self.tile_dir: ../data/triplets/175anchor.npy
#
#
# self.tile_dir: ../data/triplets/258anchor.npy
#
# self.tile_dir: ../data/triplets/206anchor.npy
#
# self.tile_dir: ../data/triplets/390anchor.npy
#
# self.tile_dir: ../data/triplets/221anchor.npy
# self.tile_dir: ../data/triplets/203anchor.npy
#
#
# self.tile_dir: ../data/triplets/296anchor.npy
#
# self.tile_dir: ../data/triplets/376anchor.npy
# self.tile_dir: ../data/triplets/379anchor.npy
#
#
# self.tile_dir: ../data/triplets/35anchor.npy
#
# self.tile_dir: ../data/triplets/112anchor.npy
# self.tile_dir: ../data/triplets/429anchor.npy
#
#
# self.tile_dir: ../data/triplets/256anchor.npy
#
# self.tile_dir: ../data/triplets/198anchor.npy
#
# self.tile_dir: ../data/triplets/381anchor.npy
#
# self.tile_dir: ../data/triplets/404anchor.npy
#
# self.tile_dir: ../data/triplets/425anchor.npy
#
# self.tile_dir: ../data/triplets/341anchor.npy
#
# self.tile_dir: ../data/triplets/466anchor.npy
#
# self.tile_dir: ../data/triplets/447anchor.npy
#
# self.tile_dir: ../data/triplets/345anchor.npy
# self.tile_dir: ../data/triplets/120anchor.npy
# self.tile_dir: ../data/triplets/119anchor.npy
#
#
# self.tile_dir: ../data/triplets/217anchor.npy
# self.tile_dir: ../data/triplets/224anchor.npy
#
#
# self.tile_dir: ../data/triplets/17anchor.npy
# self.tile_dir: ../data/triplets/125anchor.npy
#
#
# self.tile_dir: ../data/triplets/300anchor.npy
# self.tile_dir: ../data/triplets/428anchor.npy
#
#
# self.tile_dir: ../data/triplets/389anchor.npy
# self.tile_dir: ../data/triplets/151anchor.npy
#
#
# self.tile_dir: ../data/triplets/214anchor.npy
#
# self.tile_dir: ../data/triplets/314anchor.npy
#
# self.tile_dir: ../data/triplets/457anchor.npy
# self.tile_dir: ../data/triplets/490anchor.npy
#
# self.tile_dir: ../data/triplets/450anchor.npy
#
# self.tile_dir: ../data/triplets/222anchor.npy
#
# self.tile_dir: ../data/triplets/432anchor.npy
#
# self.tile_dir: ../data/triplets/489anchor.npy
#
# self.tile_dir: ../data/triplets/197anchor.npy
#
# self.tile_dir: ../data/triplets/50anchor.npy
#
#
# self.tile_dir: ../data/triplets/493anchor.npy
# self.tile_dir: ../data/triplets/357anchor.npy
#
#
# self.tile_dir: ../data/triplets/287anchor.npy
# self.tile_dir: ../data/triplets/322anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/190anchor.npy
# self.tile_dir: ../data/triplets/349anchor.npy
#
#
# self.tile_dir: ../data/triplets/90anchor.npy
#
# self.tile_dir: ../data/triplets/480anchor.npy
# self.tile_dir: ../data/triplets/51anchor.npy
#
#
# self.tile_dir: ../data/triplets/434anchor.npy
#
# self.tile_dir: ../data/triplets/232anchor.npy
#
# self.tile_dir: ../data/triplets/317anchor.npy
#
# self.tile_dir: ../data/triplets/185anchor.npy
#
# self.tile_dir: ../data/triplets/273anchor.npy
#
# self.tile_dir: ../data/triplets/421anchor.npy
#
# self.tile_dir: ../data/triplets/43anchor.npy
#
# self.tile_dir: ../data/triplets/323anchor.npy
#
# self.tile_dir: ../data/triplets/160anchor.npy
# self.tile_dir: ../data/triplets/488anchor.npy
#
#
# self.tile_dir: ../data/triplets/188anchor.npy
#
# self.tile_dir: ../data/triplets/324anchor.npy
# self.tile_dir: ../data/triplets/181anchor.npy
#
#
# self.tile_dir: ../data/triplets/382anchor.npy
#
# self.tile_dir: ../data/triplets/444anchor.npy
# self.tile_dir: ../data/triplets/189anchor.npy
#
# self.tile_dir: ../data/triplets/5anchor.npy
#
#
# self.tile_dir: ../data/triplets/332anchor.npy
# self.tile_dir: ../data/triplets/75anchor.npy
# self.tile_dir: ../data/triplets/204anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/121anchor.npy
# self.tile_dir: ../data/triplets/335anchor.npy
#
# self.tile_dir: ../data/triplets/374anchor.npy
#
#
# self.tile_dir: ../data/triplets/459anchor.npy
# self.tile_dir: ../data/triplets/8anchor.npy
# self.tile_dir: ../data/triplets/201anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/378anchor.npy
# self.tile_dir: ../data/triplets/233anchor.npy
# self.tile_dir: ../data/triplets/448anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/343anchor.npy
# self.tile_dir: ../data/triplets/265anchor.npy
#
# self.tile_dir: ../data/triplets/318anchor.npy
#
#
# self.tile_dir: ../data/triplets/162anchor.npy
# self.tile_dir: ../data/triplets/107anchor.npy
# self.tile_dir: ../data/triplets/33anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/137anchor.npy
#
# self.tile_dir: ../data/triplets/246anchor.npy
#
# self.tile_dir: ../data/triplets/40anchor.npy
# self.tile_dir: ../data/triplets/437anchor.npy
#
#
# self.tile_dir: ../data/triplets/141anchor.npy
#
# self.tile_dir: ../data/triplets/262anchor.npy
#
# self.tile_dir: ../data/triplets/462anchor.npy
#
# self.tile_dir: ../data/triplets/156anchor.npy
#
# self.tile_dir: ../data/triplets/47anchor.npy
#
# self.tile_dir: ../data/triplets/74anchor.npy
#
# self.tile_dir: ../data/triplets/406anchor.npy
#
# self.tile_dir: ../data/triplets/465anchor.npy
#
# self.tile_dir: ../data/triplets/223anchor.npy
#
# self.tile_dir: ../data/triplets/187anchor.npy
#
# self.tile_dir: ../data/triplets/337anchor.npy
#
# self.tile_dir: ../data/triplets/498anchor.npy
#
# self.tile_dir: ../data/triplets/491anchor.npy
#
# self.tile_dir: ../data/triplets/2anchor.npy
#
# self.tile_dir: ../data/triplets/42anchor.npy
# self.tile_dir: ../data/triplets/59anchor.npy
#
#
# self.tile_dir: ../data/triplets/39anchor.npy
# self.tile_dir: ../data/triplets/267anchor.npy
#
#
# self.tile_dir: ../data/triplets/351anchor.npy
# self.tile_dir: ../data/triplets/483anchor.npy
#
#
# self.tile_dir: ../data/triplets/77anchor.npy
#
# self.tile_dir: ../data/triplets/29anchor.npy
#
# self.tile_dir: ../data/triplets/127anchor.npy
#
# self.tile_dir: ../data/triplets/460anchor.npy
#
# self.tile_dir: ../data/triplets/209anchor.npy
#
# self.tile_dir: ../data/triplets/497anchor.npy
#
# self.tile_dir: ../data/triplets/417anchor.npy
#
# self.tile_dir: ../data/triplets/308anchor.npy
#
# self.tile_dir: ../data/triplets/114anchor.npy
#
# self.tile_dir: ../data/triplets/165anchor.npy
#
# self.tile_dir: ../data/triplets/285anchor.npy
#
# self.tile_dir: ../data/triplets/315anchor.npy
#
# self.tile_dir: ../data/triplets/14anchor.npy
#
# self.tile_dir: ../data/triplets/342anchor.npy
#
# self.tile_dir: ../data/triplets/37anchor.npy
#
# self.tile_dir: ../data/triplets/242anchor.npy
#
# self.tile_dir: ../data/triplets/104anchor.npy
#
# self.tile_dir: ../data/triplets/253anchor.npy
# self.tile_dir: ../data/triplets/383anchor.npy
#
# self.tile_dir: ../data/triplets/32anchor.npy
#
# self.tile_dir: ../data/triplets/78anchor.npy
#
#
# self.tile_dir: ../data/triplets/143anchor.npy
# self.tile_dir: ../data/triplets/371anchor.npy
#
#
# self.tile_dir: ../data/triplets/9anchor.npy
# self.tile_dir: ../data/triplets/200anchor.npy
#
#
# self.tile_dir: ../data/triplets/199anchor.npy
# self.tile_dir: ../data/triplets/93anchor.npy
#
#
# self.tile_dir: ../data/triplets/26anchor.npy
# self.tile_dir: ../data/triplets/62anchor.npy
#
#
# self.tile_dir: ../data/triplets/36anchor.npy
# self.tile_dir: ../data/triplets/44anchor.npy
#
#
# self.tile_dir: ../data/triplets/452anchor.npy
# self.tile_dir: ../data/triplets/419anchor.npy
#
#
# self.tile_dir: ../data/triplets/27anchor.npy
# self.tile_dir: ../data/triplets/85anchor.npy
#
#
# self.tile_dir: ../data/triplets/440anchor.npy
#
# self.tile_dir: ../data/triplets/325anchor.npy
#
# self.tile_dir: ../data/triplets/87anchor.npy
#
# self.tile_dir: ../data/triplets/485anchor.npy
#
# self.tile_dir: ../data/triplets/495anchor.npy
#
# self.tile_dir: ../data/triplets/306anchor.npy
#
# self.tile_dir: ../data/triplets/278anchor.npy
#
# self.tile_dir: ../data/triplets/244anchor.npy
#
# self.tile_dir: ../data/triplets/145anchor.npy
#
# self.tile_dir: ../data/triplets/140anchor.npy
#
# self.tile_dir: ../data/triplets/361anchor.npy
#
# self.tile_dir: ../data/triplets/380anchor.npy
#
# self.tile_dir: ../data/triplets/391anchor.npy
#
# self.tile_dir: ../data/triplets/177anchor.npy
#
# self.tile_dir: ../data/triplets/95anchor.npy
#
# self.tile_dir: ../data/triplets/228anchor.npy
#
# self.tile_dir: ../data/triplets/38anchor.npy
#
# self.tile_dir: ../data/triplets/82anchor.npy
#
# self.tile_dir: ../data/triplets/294anchor.npy
#
# self.tile_dir: ../data/triplets/153anchor.npy
#
# self.tile_dir: ../data/triplets/91anchor.npy
#
# self.tile_dir: ../data/triplets/319anchor.npy
#
# self.tile_dir: ../data/triplets/397anchor.npy
#
# self.tile_dir: ../data/triplets/240anchor.npy
#
# self.tile_dir: ../data/triplets/356anchor.npy
#
# self.tile_dir: ../data/triplets/277anchor.npy
#
# self.tile_dir: ../data/triplets/424anchor.npy
#
# self.tile_dir: ../data/triplets/415anchor.npy
# self.tile_dir: ../data/triplets/362anchor.npy
#
#
# self.tile_dir: ../data/triplets/211anchor.npy
# self.tile_dir: ../data/triplets/353anchor.npy
#
#
# self.tile_dir: ../data/triplets/103anchor.npy
# self.tile_dir: ../data/triplets/97anchor.npy
#
#
# self.tile_dir: ../data/triplets/154anchor.npy
# self.tile_dir: ../data/triplets/53anchor.npy
#
#
# self.tile_dir: ../data/triplets/106anchor.npy
# self.tile_dir: ../data/triplets/411anchor.npy
#
#
# self.tile_dir: ../data/triplets/270anchor.npy
# self.tile_dir: ../data/triplets/251anchor.npy
#
#
# self.tile_dir: ../data/triplets/254anchor.npy
# self.tile_dir: ../data/triplets/30anchor.npy
#
#
# self.tile_dir: ../data/triplets/269anchor.npy
# self.tile_dir: ../data/triplets/365anchor.npy
#
#
# self.tile_dir: ../data/triplets/336anchor.npy
#
# self.tile_dir: ../data/triplets/451anchor.npy
#
# self.tile_dir: ../data/triplets/229anchor.npy
#
# self.tile_dir: ../data/triplets/257anchor.npy
#
# self.tile_dir: ../data/triplets/109anchor.npy
#
# self.tile_dir: ../data/triplets/304anchor.npy
#
# self.tile_dir: ../data/triplets/475anchor.npy
#
# self.tile_dir: ../data/triplets/164anchor.npy
#
# self.tile_dir: ../data/triplets/159anchor.npy
#
# self.tile_dir: ../data/triplets/482anchor.npy
#
# self.tile_dir: ../data/triplets/487anchor.npy
#
# self.tile_dir: ../data/triplets/134anchor.npy
#
# self.tile_dir: ../data/triplets/184anchor.npy
#
# self.tile_dir: ../data/triplets/58anchor.npy
#
# self.tile_dir: ../data/triplets/455anchor.npy
#
# self.tile_dir: ../data/triplets/259anchor.npy
#
# self.tile_dir: ../data/triplets/456anchor.npy
#
# self.tile_dir: ../data/triplets/359anchor.npy
#
# self.tile_dir: ../data/triplets/320anchor.npy
#
# self.tile_dir: ../data/triplets/146anchor.npy
# self.tile_dir: ../data/triplets/297anchor.npy
#
#
# self.tile_dir: ../data/triplets/86anchor.npy
#
# self.tile_dir: ../data/triplets/136anchor.npy
#
# self.tile_dir: ../data/triplets/135anchor.npy
#
# self.tile_dir: ../data/triplets/155anchor.npy
# self.tile_dir: ../data/triplets/255anchor.npy
#
#
# self.tile_dir: ../data/triplets/470anchor.npy
#
# self.tile_dir: ../data/triplets/34anchor.npy
# self.tile_dir: ../data/triplets/474anchor.npy
# self.tile_dir: ../data/triplets/438anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/182anchor.npy
# self.tile_dir: ../data/triplets/375anchor.npy
#
# self.tile_dir: ../data/triplets/24anchor.npy
#
#
# self.tile_dir: ../data/triplets/148anchor.npy
#
# self.tile_dir: ../data/triplets/13anchor.npy
#
# self.tile_dir: ../data/triplets/339anchor.npy
#
# self.tile_dir: ../data/triplets/302anchor.npy
# self.tile_dir: ../data/triplets/180anchor.npy
#
#
# self.tile_dir: ../data/triplets/454anchor.npy
#
# self.tile_dir: ../data/triplets/442anchor.npy
# self.tile_dir: ../data/triplets/484anchor.npy
#
#
# self.tile_dir: ../data/triplets/395anchor.npy
#
# self.tile_dir: ../data/triplets/191anchor.npy
#
# self.tile_dir: ../data/triplets/176anchor.npy
# self.tile_dir: ../data/triplets/218anchor.npy
#
#
# self.tile_dir: ../data/triplets/235anchor.npy
#
# self.tile_dir: ../data/triplets/169anchor.npy
# self.tile_dir: ../data/triplets/288anchor.npy
#
#
# self.tile_dir: ../data/triplets/477anchor.npy
#
# self.tile_dir: ../data/triplets/196anchor.npy
# self.tile_dir: ../data/triplets/84anchor.npy
#
#
# self.tile_dir: ../data/triplets/446anchor.npy
#
# self.tile_dir: ../data/triplets/81anchor.npy
# self.tile_dir: ../data/triplets/409anchor.npy
#
#
# self.tile_dir: ../data/triplets/364anchor.npy
#
# self.tile_dir: ../data/triplets/80anchor.npy
# self.tile_dir: ../data/triplets/292anchor.npy
#
# self.tile_dir: ../data/triplets/57anchor.npy
#
#
# self.tile_dir: ../data/triplets/492anchor.npy
# self.tile_dir: ../data/triplets/152anchor.npy
#
# self.tile_dir: ../data/triplets/239anchor.npy
#
#
# self.tile_dir: ../data/triplets/313anchor.npy
#
# self.tile_dir: ../data/triplets/110anchor.npy
# self.tile_dir: ../data/triplets/220anchor.npy
#
#
# self.tile_dir: ../data/triplets/178anchor.npy
#
# self.tile_dir: ../data/triplets/352anchor.npy
# self.tile_dir: ../data/triplets/370anchor.npy
# self.tile_dir: ../data/triplets/388anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/377anchor.npy
#
# self.tile_dir: ../data/triplets/99anchor.npy
# self.tile_dir: ../data/triplets/157anchor.npy
#
#
# self.tile_dir: ../data/triplets/387anchor.npy
#
# self.tile_dir: ../data/triplets/386anchor.npy
# self.tile_dir: ../data/triplets/433anchor.npy
#
# self.tile_dir: ../data/triplets/309anchor.npy
#
#
# self.tile_dir: ../data/triplets/398anchor.npy
# self.tile_dir: ../data/triplets/186anchor.npy
# self.tile_dir: ../data/triplets/281anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/347anchor.npy
#
# self.tile_dir: ../data/triplets/138anchor.npy
# self.tile_dir: ../data/triplets/331anchor.npy
#
# self.tile_dir: ../data/triplets/400anchor.npy
#
#
# self.tile_dir: ../data/triplets/216anchor.npy
# self.tile_dir: ../data/triplets/443anchor.npy
# self.tile_dir: ../data/triplets/274anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/123anchor.npy
# self.tile_dir: ../data/triplets/299anchor.npy
#
#
# self.tile_dir: ../data/triplets/170anchor.npy
#
# self.tile_dir: ../data/triplets/486anchor.npy
# self.tile_dir: ../data/triplets/179anchor.npy
# self.tile_dir: ../data/triplets/427anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/305anchor.npy
# self.tile_dir: ../data/triplets/266anchor.npy
# self.tile_dir: ../data/triplets/414anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/385anchor.npy
# self.tile_dir: ../data/triplets/60anchor.npy
# self.tile_dir: ../data/triplets/478anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/215anchor.npy
#
# self.tile_dir: ../data/triplets/413anchor.npy
# self.tile_dir: ../data/triplets/367anchor.npy
#
#
# self.tile_dir: ../data/triplets/102anchor.npy
#
# self.tile_dir: ../data/triplets/61anchor.npy
# self.tile_dir: ../data/triplets/166anchor.npy
#
#
# self.tile_dir: ../data/triplets/283anchor.npy
#
# self.tile_dir: ../data/triplets/1anchor.npy
# self.tile_dir: ../data/triplets/20anchor.npy
#
#
# self.tile_dir: ../data/triplets/328anchor.npy
#
# self.tile_dir: ../data/triplets/18anchor.npy
# self.tile_dir: ../data/triplets/69anchor.npy
#
#
# self.tile_dir: ../data/triplets/122anchor.npy
#
# self.tile_dir: ../data/triplets/171anchor.npy
#
# self.tile_dir: ../data/triplets/117anchor.npy
#
# self.tile_dir: ../data/triplets/12anchor.npy
#
# self.tile_dir: ../data/triplets/301anchor.npy
#
# self.tile_dir: ../data/triplets/295anchor.npy
#
# self.tile_dir: ../data/triplets/268anchor.npy
#
# self.tile_dir: ../data/triplets/441anchor.npy
#
# self.tile_dir: ../data/triplets/163anchor.npy
#
# self.tile_dir: ../data/triplets/358anchor.npy
#
# self.tile_dir: ../data/triplets/418anchor.npy
#
# self.tile_dir: ../data/triplets/133anchor.npy
# self.tile_dir: ../data/triplets/346anchor.npy
#
#
# self.tile_dir: ../data/triplets/23anchor.npy
#
# self.tile_dir: ../data/triplets/481anchor.npy
#
# self.tile_dir: ../data/triplets/115anchor.npy
#
# self.tile_dir: ../data/triplets/310anchor.npy
#
# self.tile_dir: ../data/triplets/384anchor.npy
# self.tile_dir: ../data/triplets/25anchor.npy
#
#
# self.tile_dir: ../data/triplets/68anchor.npy
#
# self.tile_dir: ../data/triplets/21anchor.npy
# self.tile_dir: ../data/triplets/108anchor.npy
#
# self.tile_dir: ../data/triplets/426anchor.npy
#
#
# self.tile_dir: ../data/triplets/219anchor.npy
# self.tile_dir: ../data/triplets/467anchor.npy
#
#
# self.tile_dir: ../data/triplets/128anchor.npy
#
# self.tile_dir: ../data/triplets/130anchor.npy
# self.tile_dir: ../data/triplets/52anchor.npy
#
#
# self.tile_dir: ../data/triplets/469anchor.npy
#
# self.tile_dir: ../data/triplets/247anchor.npy
# self.tile_dir: ../data/triplets/195anchor.npy
#
#
# self.tile_dir: ../data/triplets/435anchor.npy
#
# self.tile_dir: ../data/triplets/363anchor.npy
# self.tile_dir: ../data/triplets/436anchor.npy
#
#
# self.tile_dir: ../data/triplets/15anchor.npy
#
# self.tile_dir: ../data/triplets/202anchor.npy
# self.tile_dir: ../data/triplets/271anchor.npy
#
# self.tile_dir: ../data/triplets/373anchor.npy
#
#
# self.tile_dir: ../data/triplets/430anchor.npy
# self.tile_dir: ../data/triplets/311anchor.npy
#
# self.tile_dir: ../data/triplets/396anchor.npy
#
#
# self.tile_dir: ../data/triplets/7anchor.npy
# self.tile_dir: ../data/triplets/31anchor.npy
#
# self.tile_dir: ../data/triplets/0anchor.npy
#
#
# self.tile_dir: ../data/triplets/139anchor.npy
#
# self.tile_dir: ../data/triplets/241anchor.npy
# self.tile_dir: ../data/triplets/144anchor.npy
#
#
# self.tile_dir: ../data/triplets/316anchor.npy
#
# self.tile_dir: ../data/triplets/192anchor.npy
# self.tile_dir: ../data/triplets/276anchor.npy
#
#
# self.tile_dir: ../data/triplets/149anchor.npy
# self.tile_dir: ../data/triplets/205anchor.npy
#
#
# self.tile_dir: ../data/triplets/55anchor.npy
#
# self.tile_dir: ../data/triplets/312anchor.npy
#
# self.tile_dir: ../data/triplets/230anchor.npy
#
# self.tile_dir: ../data/triplets/252anchor.npy
#
# self.tile_dir: ../data/triplets/348anchor.npy
#
# self.tile_dir: ../data/triplets/72anchor.npy
#
# self.tile_dir: ../data/triplets/439anchor.npy
#
# self.tile_dir: ../data/triplets/350anchor.npy
#
# self.tile_dir: ../data/triplets/307anchor.npy
#
# self.tile_dir: ../data/triplets/410anchor.npy
#
# self.tile_dir: ../data/triplets/369anchor.npy
#
# self.tile_dir: ../data/triplets/113anchor.npy
#
# self.tile_dir: ../data/triplets/11anchor.npy
#
# self.tile_dir: ../data/triplets/161anchor.npy
#
# self.tile_dir: ../data/triplets/236anchor.npy
#
# self.tile_dir: ../data/triplets/399anchor.npy
#
# self.tile_dir: ../data/triplets/298anchor.npy
#
# self.tile_dir: ../data/triplets/321anchor.npy
#
# self.tile_dir: ../data/triplets/472anchor.npy
#
# self.tile_dir: ../data/triplets/10anchor.npy
#
# self.tile_dir: ../data/triplets/416anchor.npy
#
# self.tile_dir: ../data/triplets/89anchor.npy
#
# self.tile_dir: ../data/triplets/394anchor.npy
#
# self.tile_dir: ../data/triplets/116anchor.npy
#
# self.tile_dir: ../data/triplets/225anchor.npy
#
# self.tile_dir: ../data/triplets/372anchor.npy
#
# self.tile_dir: ../data/triplets/282anchor.npy
#
# self.tile_dir: ../data/triplets/263anchor.npy
#
# self.tile_dir: ../data/triplets/468anchor.npy
#
# self.tile_dir: ../data/triplets/408anchor.npy
#
# self.tile_dir: ../data/triplets/70anchor.npy
#
# self.tile_dir: ../data/triplets/449anchor.npy
#
# self.tile_dir: ../data/triplets/286anchor.npy
#
# self.tile_dir: ../data/triplets/16anchor.npy
#
# self.tile_dir: ../data/triplets/142anchor.npy
#
# self.tile_dir: ../data/triplets/231anchor.npy
#
# self.tile_dir: ../data/triplets/167anchor.npy
#
# self.tile_dir: ../data/triplets/431anchor.npy
#
# self.tile_dir: ../data/triplets/63anchor.npy
#
# self.tile_dir: ../data/triplets/67anchor.npy
#
# self.tile_dir: ../data/triplets/111anchor.npy
#
# self.tile_dir: ../data/triplets/248anchor.npy
#
# self.tile_dir: ../data/triplets/275anchor.npy
#
# self.tile_dir: ../data/triplets/334anchor.npy
#
# self.tile_dir: ../data/triplets/264anchor.npy
#
# self.tile_dir: ../data/triplets/463anchor.npy
#
# self.tile_dir: ../data/triplets/48anchor.npy
#
# self.tile_dir: ../data/triplets/420anchor.npy
#
# self.tile_dir: ../data/triplets/172anchor.npy
#
# self.tile_dir: ../data/triplets/213anchor.npy
#
# self.tile_dir: ../data/triplets/422anchor.npy
#
# self.tile_dir: ../data/triplets/272anchor.npy
#
# self.tile_dir: ../data/triplets/45anchor.npy
#
# self.tile_dir: ../data/triplets/129anchor.npy
#
# self.tile_dir: ../data/triplets/476anchor.npy
#
# self.tile_dir: ../data/triplets/54anchor.npy
#
# self.tile_dir: ../data/triplets/73anchor.npy
#
# self.tile_dir: ../data/triplets/131anchor.npy
#
# self.tile_dir: ../data/triplets/98anchor.npy
#
# self.tile_dir: ../data/triplets/329anchor.npy
#
# self.tile_dir: ../data/triplets/250anchor.npy
#
# self.tile_dir: ../data/triplets/407anchor.npy
#
# self.tile_dir: ../data/triplets/22anchor.npy
#
# self.tile_dir: ../data/triplets/354anchor.npy
#
# self.tile_dir: ../data/triplets/499anchor.npy
#
# self.tile_dir: ../data/triplets/147anchor.npy
#
# self.tile_dir: ../data/triplets/237anchor.npy
#
# self.tile_dir: ../data/triplets/208anchor.npy
#
# self.tile_dir: ../data/triplets/71anchor.npy
#
# self.tile_dir: ../data/triplets/41anchor.npy
#
# self.tile_dir: ../data/triplets/260anchor.npy
#
# self.tile_dir: ../data/triplets/19anchor.npy
#
# self.tile_dir: ../data/triplets/453anchor.npy
#
# self.tile_dir: ../data/triplets/494anchor.npy
#
# self.tile_dir: ../data/triplets/3anchor.npy
#
# self.tile_dir: ../data/triplets/65anchor.npy
#
# self.tile_dir: ../data/triplets/212anchor.npy
#
# self.tile_dir: ../data/triplets/49anchor.npy
#
# self.tile_dir: ../data/triplets/105anchor.npy
#
# self.tile_dir: ../data/triplets/83anchor.npy
#
# self.tile_dir: ../data/triplets/402anchor.npy
#
# self.tile_dir: ../data/triplets/261anchor.npy
#
# self.tile_dir: ../data/triplets/64anchor.npy
#
# self.tile_dir: ../data/triplets/126anchor.npy
#
# self.tile_dir: ../data/triplets/79anchor.npy
#
# self.tile_dir: ../data/triplets/284anchor.npy
#
# self.tile_dir: ../data/triplets/193anchor.npy
#
# self.tile_dir: ../data/triplets/227anchor.npy
#
# self.tile_dir: ../data/triplets/28anchor.npy
#
# self.tile_dir: ../data/triplets/401anchor.npy
#
# self.tile_dir: ../data/triplets/92anchor.npy
#
# self.tile_dir: ../data/triplets/168anchor.npy
#
# self.tile_dir: ../data/triplets/290anchor.npy
#
# self.tile_dir: ../data/triplets/96anchor.npy
#
# self.tile_dir: ../data/triplets/303anchor.npy
#
# self.tile_dir: ../data/triplets/226anchor.npy
#
# self.tile_dir: ../data/triplets/291anchor.npy
#
# self.tile_dir: ../data/triplets/183anchor.npy
#
# self.tile_dir: ../data/triplets/368anchor.npy
#
# self.tile_dir: ../data/triplets/279anchor.npy
#
# self.tile_dir: ../data/triplets/366anchor.npy
#
# self.tile_dir: ../data/triplets/100anchor.npy
#
# self.tile_dir: ../data/triplets/405anchor.npy
#
# self.tile_dir: ../data/triplets/174anchor.npy
#
# self.tile_dir: ../data/triplets/243anchor.npy
#
# self.tile_dir: ../data/triplets/94anchor.npy
#
# self.tile_dir: ../data/triplets/338anchor.npy
#
# self.tile_dir: ../data/triplets/403anchor.npy
#
# Finished epoch 1: 3.852s
#   Average loss: 7.4001
#   Average l_n: 5.4583
#   Average l_d: -18.2811
#   Average l_nd: -12.8227
#
# self.tile_dir: ../data/triplets/32anchor.npy
#
# self.tile_dir: ../data/triplets/374anchor.npy
#
# self.tile_dir: ../data/triplets/354anchor.npy
#
# self.tile_dir: ../data/triplets/273anchor.npy
#
# self.tile_dir: ../data/triplets/324anchor.npy
#
# self.tile_dir: ../data/triplets/491anchor.npy
#
# self.tile_dir: ../data/triplets/47anchor.npy
#
# self.tile_dir: ../data/triplets/152anchor.npy
#
# self.tile_dir: ../data/triplets/213anchor.npy
#
# self.tile_dir: ../data/triplets/379anchor.npy
#
# self.tile_dir: ../data/triplets/155anchor.npy
#
# self.tile_dir: ../data/triplets/333anchor.npy
#
# self.tile_dir: ../data/triplets/394anchor.npy
#
# self.tile_dir: ../data/triplets/311anchor.npy
#
# self.tile_dir: ../data/triplets/99anchor.npy
# self.tile_dir: ../data/triplets/97anchor.npy
#
# self.tile_dir: ../data/triplets/303anchor.npy
#
# self.tile_dir: ../data/triplets/275anchor.npy
#
# self.tile_dir: ../data/triplets/302anchor.npy
#
#
# self.tile_dir: ../data/triplets/86anchor.npy
# self.tile_dir: ../data/triplets/298anchor.npy
#
#
# self.tile_dir: ../data/triplets/372anchor.npy
#
# self.tile_dir: ../data/triplets/271anchor.npy
#
# self.tile_dir: ../data/triplets/27anchor.npy
#
# self.tile_dir: ../data/triplets/51anchor.npy
#
# self.tile_dir: ../data/triplets/404anchor.npy
# self.tile_dir: ../data/triplets/142anchor.npy
#
# self.tile_dir: ../data/triplets/439anchor.npy
#
# self.tile_dir: ../data/triplets/130anchor.npy
#
# self.tile_dir: ../data/triplets/349anchor.npy
#
#
# self.tile_dir: ../data/triplets/236anchor.npy
#
# self.tile_dir: ../data/triplets/451anchor.npy
#
# self.tile_dir: ../data/triplets/225anchor.npy
#
# self.tile_dir: ../data/triplets/237anchor.npy
#
# self.tile_dir: ../data/triplets/242anchor.npy
#
# self.tile_dir: ../data/triplets/41anchor.npy
#
# self.tile_dir: ../data/triplets/68anchor.npy
#
# self.tile_dir: ../data/triplets/426anchor.npy
#
# self.tile_dir: ../data/triplets/314anchor.npy
#
# self.tile_dir: ../data/triplets/151anchor.npy
#
# self.tile_dir: ../data/triplets/46anchor.npy
#
# self.tile_dir: ../data/triplets/355anchor.npy
#
# self.tile_dir: ../data/triplets/188anchor.npy
# self.tile_dir: ../data/triplets/217anchor.npy
#
#
# self.tile_dir: ../data/triplets/272anchor.npy
#
# self.tile_dir: ../data/triplets/64anchor.npy
# self.tile_dir: ../data/triplets/131anchor.npy
#
#
# self.tile_dir: ../data/triplets/61anchor.npy
#
# self.tile_dir: ../data/triplets/185anchor.npy
# self.tile_dir: ../data/triplets/413anchor.npy
#
#
# self.tile_dir: ../data/triplets/356anchor.npy
#
# self.tile_dir: ../data/triplets/77anchor.npy
# self.tile_dir: ../data/triplets/70anchor.npy
#
#
# self.tile_dir: ../data/triplets/250anchor.npy
#
# self.tile_dir: ../data/triplets/328anchor.npy
# self.tile_dir: ../data/triplets/309anchor.npy
#
#
# self.tile_dir: ../data/triplets/484anchor.npy
#
# self.tile_dir: ../data/triplets/116anchor.npy
# self.tile_dir: ../data/triplets/122anchor.npy
#
#
# self.tile_dir: ../data/triplets/436anchor.npy
#
# self.tile_dir: ../data/triplets/73anchor.npy
#
# self.tile_dir: ../data/triplets/220anchor.npy
#
# self.tile_dir: ../data/triplets/255anchor.npy
#
# self.tile_dir: ../data/triplets/274anchor.npy
#
# self.tile_dir: ../data/triplets/395anchor.npy
#
# self.tile_dir: ../data/triplets/264anchor.npy
#
# self.tile_dir: ../data/triplets/35anchor.npy
#
# self.tile_dir: ../data/triplets/471anchor.npy
# self.tile_dir: ../data/triplets/468anchor.npy
#
#
# self.tile_dir: ../data/triplets/128anchor.npy
# self.tile_dir: ../data/triplets/91anchor.npy
#
# self.tile_dir: ../data/triplets/148anchor.npy
#
#
# self.tile_dir: ../data/triplets/121anchor.npy
# self.tile_dir: ../data/triplets/464anchor.npy
#
# self.tile_dir: ../data/triplets/53anchor.npy
#
#
# self.tile_dir: ../data/triplets/268anchor.npy
#
# self.tile_dir: ../data/triplets/71anchor.npy
# self.tile_dir: ../data/triplets/262anchor.npy
#
#
# self.tile_dir: ../data/triplets/381anchor.npy
# self.tile_dir: ../data/triplets/482anchor.npy
#
#
# self.tile_dir: ../data/triplets/259anchor.npy
#
# self.tile_dir: ../data/triplets/143anchor.npy
#
# self.tile_dir: ../data/triplets/441anchor.npy
# self.tile_dir: ../data/triplets/19anchor.npy
#
#
# self.tile_dir: ../data/triplets/485anchor.npy
#
# self.tile_dir: ../data/triplets/429anchor.npy
# self.tile_dir: ../data/triplets/57anchor.npy
#
#
# self.tile_dir: ../data/triplets/247anchor.npy
#
# self.tile_dir: ../data/triplets/256anchor.npy
# self.tile_dir: ../data/triplets/224anchor.npy
#
#
# self.tile_dir: ../data/triplets/251anchor.npy
#
# self.tile_dir: ../data/triplets/202anchor.npy
# self.tile_dir: ../data/triplets/168anchor.npy
#
#
# self.tile_dir: ../data/triplets/390anchor.npy
#
# self.tile_dir: ../data/triplets/96anchor.npy
# self.tile_dir: ../data/triplets/176anchor.npy
#
# self.tile_dir: ../data/triplets/209anchor.npy
#
#
# self.tile_dir: ../data/triplets/85anchor.npy
#
# self.tile_dir: ../data/triplets/347anchor.npy
#
# self.tile_dir: ../data/triplets/231anchor.npy
#
# self.tile_dir: ../data/triplets/159anchor.npy
#
# self.tile_dir: ../data/triplets/235anchor.npy
# self.tile_dir: ../data/triplets/297anchor.npy
#
#
# self.tile_dir: ../data/triplets/362anchor.npy
# self.tile_dir: ../data/triplets/184anchor.npy
#
#
# self.tile_dir: ../data/triplets/195anchor.npy
# self.tile_dir: ../data/triplets/405anchor.npy
#
#
# self.tile_dir: ../data/triplets/495anchor.npy
# self.tile_dir: ../data/triplets/488anchor.npy
#
#
# self.tile_dir: ../data/triplets/160anchor.npy
# self.tile_dir: ../data/triplets/25anchor.npy
#
#
# self.tile_dir: ../data/triplets/417anchor.npy
# self.tile_dir: ../data/triplets/6anchor.npy
#
#
# self.tile_dir: ../data/triplets/458anchor.npy
# self.tile_dir: ../data/triplets/43anchor.npy
#
#
# self.tile_dir: ../data/triplets/440anchor.npy
# self.tile_dir: ../data/triplets/305anchor.npy
#
#
# self.tile_dir: ../data/triplets/300anchor.npy
# self.tile_dir: ../data/triplets/146anchor.npy
#
#
# self.tile_dir: ../data/triplets/473anchor.npy
# self.tile_dir: ../data/triplets/469anchor.npy
#
#
# self.tile_dir: ../data/triplets/5anchor.npy
#
# self.tile_dir: ../data/triplets/398anchor.npy
# self.tile_dir: ../data/triplets/42anchor.npy
#
#
# self.tile_dir: ../data/triplets/222anchor.npy
# self.tile_dir: ../data/triplets/480anchor.npy
# self.tile_dir: ../data/triplets/175anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/475anchor.npy
# self.tile_dir: ../data/triplets/320anchor.npy
# self.tile_dir: ../data/triplets/402anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/278anchor.npy
# self.tile_dir: ../data/triplets/420anchor.npy
#
#
# self.tile_dir: ../data/triplets/55anchor.npy
#
# self.tile_dir: ../data/triplets/432anchor.npy
# self.tile_dir: ../data/triplets/153anchor.npy
#
#
# self.tile_dir: ../data/triplets/406anchor.npy
#
# self.tile_dir: ../data/triplets/115anchor.npy
# self.tile_dir: ../data/triplets/285anchor.npy
#
#
# self.tile_dir: ../data/triplets/373anchor.npy
#
# self.tile_dir: ../data/triplets/414anchor.npy
# self.tile_dir: ../data/triplets/118anchor.npy
#
#
# self.tile_dir: ../data/triplets/149anchor.npy
# self.tile_dir: ../data/triplets/397anchor.npy
#
# self.tile_dir: ../data/triplets/127anchor.npy
#
#
# self.tile_dir: ../data/triplets/31anchor.npy
# self.tile_dir: ../data/triplets/389anchor.npy
# self.tile_dir: ../data/triplets/331anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/453anchor.npy
# self.tile_dir: ../data/triplets/265anchor.npy
# self.tile_dir: ../data/triplets/369anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/113anchor.npy
# self.tile_dir: ../data/triplets/29anchor.npy
#
# self.tile_dir: ../data/triplets/58anchor.npy
#
#
# self.tile_dir: ../data/triplets/461anchor.npy
#
# self.tile_dir: ../data/triplets/299anchor.npy
#
# self.tile_dir: ../data/triplets/421anchor.npy
# self.tile_dir: ../data/triplets/63anchor.npy
#
#
# self.tile_dir: ../data/triplets/248anchor.npy
# self.tile_dir: ../data/triplets/423anchor.npy
#
#
# self.tile_dir: ../data/triplets/378anchor.npy
# self.tile_dir: ../data/triplets/26anchor.npy
#
#
# self.tile_dir: ../data/triplets/238anchor.npy
# self.tile_dir: ../data/triplets/326anchor.npy
#
#
# self.tile_dir: ../data/triplets/229anchor.npy
# self.tile_dir: ../data/triplets/336anchor.npy
#
#
# self.tile_dir: ../data/triplets/240anchor.npy
# self.tile_dir: ../data/triplets/341anchor.npy
#
#
# self.tile_dir: ../data/triplets/39anchor.npy
# self.tile_dir: ../data/triplets/200anchor.npy
#
#
# self.tile_dir: ../data/triplets/123anchor.npy
#
# self.tile_dir: ../data/triplets/8anchor.npy
#
# self.tile_dir: ../data/triplets/307anchor.npy
#
# self.tile_dir: ../data/triplets/462anchor.npy
#
# self.tile_dir: ../data/triplets/206anchor.npy
#
# self.tile_dir: ../data/triplets/276anchor.npy
#
# self.tile_dir: ../data/triplets/308anchor.npy
#
# self.tile_dir: ../data/triplets/343anchor.npy
#
# self.tile_dir: ../data/triplets/424anchor.npy
#
# self.tile_dir: ../data/triplets/219anchor.npy
#
# self.tile_dir: ../data/triplets/339anchor.npy
#
# self.tile_dir: ../data/triplets/351anchor.npy
#
# self.tile_dir: ../data/triplets/294anchor.npy
#
# self.tile_dir: ../data/triplets/191anchor.npy
#
# self.tile_dir: ../data/triplets/198anchor.npy
#
# self.tile_dir: ../data/triplets/126anchor.npy
#
# self.tile_dir: ../data/triplets/486anchor.npy
#
# self.tile_dir: ../data/triplets/434anchor.npy
#
# self.tile_dir: ../data/triplets/370anchor.npy
#
# self.tile_dir: ../data/triplets/269anchor.npy
#
# self.tile_dir: ../data/triplets/165anchor.npy
#
# self.tile_dir: ../data/triplets/10anchor.npy
#
# self.tile_dir: ../data/triplets/36anchor.npy
#
# self.tile_dir: ../data/triplets/17anchor.npy
#
# self.tile_dir: ../data/triplets/62anchor.npy
#
# self.tile_dir: ../data/triplets/234anchor.npy
# self.tile_dir: ../data/triplets/442anchor.npy
#
#
# self.tile_dir: ../data/triplets/291anchor.npy
#
# self.tile_dir: ../data/triplets/497anchor.npy
#
# self.tile_dir: ../data/triplets/408anchor.npy
#
# self.tile_dir: ../data/triplets/162anchor.npy
#
# self.tile_dir: ../data/triplets/263anchor.npy
#
# self.tile_dir: ../data/triplets/380anchor.npy
#
# self.tile_dir: ../data/triplets/312anchor.npy
#
# self.tile_dir: ../data/triplets/448anchor.npy
#
# self.tile_dir: ../data/triplets/214anchor.npy
# self.tile_dir: ../data/triplets/101anchor.npy
#
#
# self.tile_dir: ../data/triplets/140anchor.npy
# self.tile_dir: ../data/triplets/393anchor.npy
#
#
# self.tile_dir: ../data/triplets/437anchor.npy
#
# self.tile_dir: ../data/triplets/21anchor.npy
#
# self.tile_dir: ../data/triplets/109anchor.npy
#
# self.tile_dir: ../data/triplets/258anchor.npy
#
# self.tile_dir: ../data/triplets/125anchor.npy
#
# self.tile_dir: ../data/triplets/340anchor.npy
#
# self.tile_dir: ../data/triplets/450anchor.npy
#
# self.tile_dir: ../data/triplets/319anchor.npy
#
# self.tile_dir: ../data/triplets/360anchor.npy
#
# self.tile_dir: ../data/triplets/332anchor.npy
#
# self.tile_dir: ../data/triplets/438anchor.npy
#
# self.tile_dir: ../data/triplets/181anchor.npy
#
# self.tile_dir: ../data/triplets/182anchor.npy
#
# self.tile_dir: ../data/triplets/114anchor.npy
#
# self.tile_dir: ../data/triplets/296anchor.npy
#
# self.tile_dir: ../data/triplets/290anchor.npy
#
# self.tile_dir: ../data/triplets/227anchor.npy
#
# self.tile_dir: ../data/triplets/392anchor.npy
#
# self.tile_dir: ../data/triplets/44anchor.npy
#
# self.tile_dir: ../data/triplets/323anchor.npy
#
# self.tile_dir: ../data/triplets/45anchor.npy
#
# self.tile_dir: ../data/triplets/60anchor.npy
#
# self.tile_dir: ../data/triplets/137anchor.npy
#
# self.tile_dir: ../data/triplets/66anchor.npy
#
# self.tile_dir: ../data/triplets/270anchor.npy
#
# self.tile_dir: ../data/triplets/487anchor.npy
#
# self.tile_dir: ../data/triplets/7anchor.npy
#
# self.tile_dir: ../data/triplets/16anchor.npy
#
# self.tile_dir: ../data/triplets/316anchor.npy
#
# self.tile_dir: ../data/triplets/139anchor.npy
#
# self.tile_dir: ../data/triplets/452anchor.npy
#
# self.tile_dir: ../data/triplets/364anchor.npy
#
# self.tile_dir: ../data/triplets/344anchor.npy
#
# self.tile_dir: ../data/triplets/257anchor.npy
#
# self.tile_dir: ../data/triplets/317anchor.npy
#
# self.tile_dir: ../data/triplets/396anchor.npy
#
# self.tile_dir: ../data/triplets/38anchor.npy
#
# self.tile_dir: ../data/triplets/386anchor.npy
#
# self.tile_dir: ../data/triplets/95anchor.npy
#
# self.tile_dir: ../data/triplets/212anchor.npy
#
# self.tile_dir: ../data/triplets/249anchor.npy
#
# self.tile_dir: ../data/triplets/435anchor.npy
# self.tile_dir: ../data/triplets/447anchor.npy
#
#
# self.tile_dir: ../data/triplets/178anchor.npy
#
# self.tile_dir: ../data/triplets/34anchor.npy
#
# self.tile_dir: ../data/triplets/186anchor.npy
#
# self.tile_dir: ../data/triplets/352anchor.npy
#
# self.tile_dir: ../data/triplets/156anchor.npy
#
# self.tile_dir: ../data/triplets/306anchor.npy
#
# self.tile_dir: ../data/triplets/359anchor.npy
#
# self.tile_dir: ../data/triplets/350anchor.npy
#
# self.tile_dir: ../data/triplets/346anchor.npy
#
# self.tile_dir: ../data/triplets/407anchor.npy
#
# self.tile_dir: ../data/triplets/411anchor.npy
#
# self.tile_dir: ../data/triplets/391anchor.npy
#
# self.tile_dir: ../data/triplets/459anchor.npy
#
# self.tile_dir: ../data/triplets/174anchor.npy
#
# self.tile_dir: ../data/triplets/56anchor.npy
#
# self.tile_dir: ../data/triplets/111anchor.npy
#
# self.tile_dir: ../data/triplets/342anchor.npy
#
# self.tile_dir: ../data/triplets/103anchor.npy
#
# self.tile_dir: ../data/triplets/169anchor.npy
#
# self.tile_dir: ../data/triplets/40anchor.npy
#
# self.tile_dir: ../data/triplets/211anchor.npy
#
# self.tile_dir: ../data/triplets/401anchor.npy
#
# self.tile_dir: ../data/triplets/67anchor.npy
#
# self.tile_dir: ../data/triplets/192anchor.npy
#
# self.tile_dir: ../data/triplets/207anchor.npy
#
# self.tile_dir: ../data/triplets/348anchor.npy
#
# self.tile_dir: ../data/triplets/74anchor.npy
#
# self.tile_dir: ../data/triplets/1anchor.npy
#
# self.tile_dir: ../data/triplets/13anchor.npy
#
# self.tile_dir: ../data/triplets/23anchor.npy
#
# self.tile_dir: ../data/triplets/135anchor.npy
#
# self.tile_dir: ../data/triplets/196anchor.npy
#
# self.tile_dir: ../data/triplets/490anchor.npy
#
# self.tile_dir: ../data/triplets/310anchor.npy
#
# self.tile_dir: ../data/triplets/483anchor.npy
#
# self.tile_dir: ../data/triplets/321anchor.npy
#
# self.tile_dir: ../data/triplets/20anchor.npy
#
# self.tile_dir: ../data/triplets/107anchor.npy
#
# self.tile_dir: ../data/triplets/180anchor.npy
#
# self.tile_dir: ../data/triplets/187anchor.npy
#
# self.tile_dir: ../data/triplets/415anchor.npy
#
# self.tile_dir: ../data/triplets/318anchor.npy
#
# self.tile_dir: ../data/triplets/133anchor.npy
#
# self.tile_dir: ../data/triplets/33anchor.npy
#
# self.tile_dir: ../data/triplets/399anchor.npy
#
# self.tile_dir: ../data/triplets/52anchor.npy
#
# self.tile_dir: ../data/triplets/470anchor.npy
#
# self.tile_dir: ../data/triplets/12anchor.npy
#
# self.tile_dir: ../data/triplets/427anchor.npy
#
# self.tile_dir: ../data/triplets/0anchor.npy
# self.tile_dir: ../data/triplets/365anchor.npy
#
#
# self.tile_dir: ../data/triplets/431anchor.npy
#
# self.tile_dir: ../data/triplets/287anchor.npy
#
# self.tile_dir: ../data/triplets/117anchor.npy
#
# self.tile_dir: ../data/triplets/69anchor.npy
#
# self.tile_dir: ../data/triplets/134anchor.npy
# self.tile_dir: ../data/triplets/322anchor.npy
#
#
# self.tile_dir: ../data/triplets/154anchor.npy
# self.tile_dir: ../data/triplets/201anchor.npy
#
#
# self.tile_dir: ../data/triplets/9anchor.npy
# self.tile_dir: ../data/triplets/261anchor.npy
#
#
# self.tile_dir: ../data/triplets/164anchor.npy
#
# self.tile_dir: ../data/triplets/253anchor.npy
#
# self.tile_dir: ../data/triplets/301anchor.npy
#
# self.tile_dir: ../data/triplets/216anchor.npy
#
# self.tile_dir: ../data/triplets/279anchor.npy
#
# self.tile_dir: ../data/triplets/367anchor.npy
# self.tile_dir: ../data/triplets/492anchor.npy
#
#
# self.tile_dir: ../data/triplets/400anchor.npy
# self.tile_dir: ../data/triplets/163anchor.npy
#
#
# self.tile_dir: ../data/triplets/199anchor.npy
#
# self.tile_dir: ../data/triplets/472anchor.npy
#
# self.tile_dir: ../data/triplets/277anchor.npy
#
# self.tile_dir: ../data/triplets/498anchor.npy
# self.tile_dir: ../data/triplets/478anchor.npy
#
#
# self.tile_dir: ../data/triplets/387anchor.npy
# self.tile_dir: ../data/triplets/215anchor.npy
#
#
# self.tile_dir: ../data/triplets/48anchor.npy
# self.tile_dir: ../data/triplets/104anchor.npy
#
#
# self.tile_dir: ../data/triplets/183anchor.npy
# self.tile_dir: ../data/triplets/88anchor.npy
#
#
# self.tile_dir: ../data/triplets/493anchor.npy
# self.tile_dir: ../data/triplets/329anchor.npy
#
#
# self.tile_dir: ../data/triplets/489anchor.npy
# self.tile_dir: ../data/triplets/218anchor.npy
#
#
# self.tile_dir: ../data/triplets/90anchor.npy
#
# self.tile_dir: ../data/triplets/465anchor.npy
#
# self.tile_dir: ../data/triplets/157anchor.npy
#
# self.tile_dir: ../data/triplets/82anchor.npy
#
# self.tile_dir: ../data/triplets/409anchor.npy
#
# self.tile_dir: ../data/triplets/477anchor.npy
#
# self.tile_dir: ../data/triplets/345anchor.npy
#
# self.tile_dir: ../data/triplets/94anchor.npy
#
# self.tile_dir: ../data/triplets/416anchor.npy
#
# self.tile_dir: ../data/triplets/170anchor.npy
#
# self.tile_dir: ../data/triplets/433anchor.npy
#
# self.tile_dir: ../data/triplets/83anchor.npy
# self.tile_dir: ../data/triplets/197anchor.npy
#
#
# self.tile_dir: ../data/triplets/454anchor.npy
# self.tile_dir: ../data/triplets/171anchor.npy
#
#
# self.tile_dir: ../data/triplets/476anchor.npy
#
# self.tile_dir: ../data/triplets/357anchor.npy
#
# self.tile_dir: ../data/triplets/430anchor.npy
#
# self.tile_dir: ../data/triplets/479anchor.npy
#
# self.tile_dir: ../data/triplets/205anchor.npy
#
# self.tile_dir: ../data/triplets/208anchor.npy
#
# self.tile_dir: ../data/triplets/132anchor.npy
#
# self.tile_dir: ../data/triplets/105anchor.npy
#
# self.tile_dir: ../data/triplets/136anchor.npy
#
# self.tile_dir: ../data/triplets/28anchor.npy
#
# self.tile_dir: ../data/triplets/161anchor.npy
#
# self.tile_dir: ../data/triplets/241anchor.npy
#
# self.tile_dir: ../data/triplets/221anchor.npy
#
# self.tile_dir: ../data/triplets/419anchor.npy
#
# self.tile_dir: ../data/triplets/304anchor.npy
#
# self.tile_dir: ../data/triplets/177anchor.npy
# self.tile_dir: ../data/triplets/24anchor.npy
#
# self.tile_dir: ../data/triplets/2anchor.npy
#
# self.tile_dir: ../data/triplets/455anchor.npy
#
# self.tile_dir: ../data/triplets/54anchor.npy
#
# self.tile_dir: ../data/triplets/282anchor.npy
#
# self.tile_dir: ../data/triplets/203anchor.npy
#
# self.tile_dir: ../data/triplets/223anchor.npy
#
#
# self.tile_dir: ../data/triplets/108anchor.npy
# self.tile_dir: ../data/triplets/232anchor.npy
#
#
# self.tile_dir: ../data/triplets/4anchor.npy
# self.tile_dir: ../data/triplets/59anchor.npy
#
#
# self.tile_dir: ../data/triplets/456anchor.npy
# self.tile_dir: ../data/triplets/144anchor.npy
#
#
# self.tile_dir: ../data/triplets/147anchor.npy
# self.tile_dir: ../data/triplets/145anchor.npy
#
#
# self.tile_dir: ../data/triplets/87anchor.npy
# self.tile_dir: ../data/triplets/76anchor.npy
#
#
# self.tile_dir: ../data/triplets/325anchor.npy
# self.tile_dir: ../data/triplets/193anchor.npy
#
#
# self.tile_dir: ../data/triplets/445anchor.npy
#
# self.tile_dir: ../data/triplets/377anchor.npy
#
# self.tile_dir: ../data/triplets/388anchor.npy
# self.tile_dir: ../data/triplets/80anchor.npy
#
#
# self.tile_dir: ../data/triplets/460anchor.npy
# self.tile_dir: ../data/triplets/228anchor.npy
#
#
# self.tile_dir: ../data/triplets/337anchor.npy
# self.tile_dir: ../data/triplets/3anchor.npy
#
#
# self.tile_dir: ../data/triplets/375anchor.npy
# self.tile_dir: ../data/triplets/102anchor.npy
#
#
# self.tile_dir: ../data/triplets/334anchor.npy
#
# self.tile_dir: ../data/triplets/89anchor.npy
#
# self.tile_dir: ../data/triplets/244anchor.npy
#
# self.tile_dir: ../data/triplets/371anchor.npy
#
# self.tile_dir: ../data/triplets/65anchor.npy
#
# self.tile_dir: ../data/triplets/267anchor.npy
#
# self.tile_dir: ../data/triplets/295anchor.npy
#
# self.tile_dir: ../data/triplets/383anchor.npy
#
# self.tile_dir: ../data/triplets/110anchor.npy
# self.tile_dir: ../data/triplets/284anchor.npy
#
#
# self.tile_dir: ../data/triplets/463anchor.npy
#
# self.tile_dir: ../data/triplets/474anchor.npy
#
# self.tile_dir: ../data/triplets/286anchor.npy
#
# self.tile_dir: ../data/triplets/129anchor.npy
#
# self.tile_dir: ../data/triplets/449anchor.npy
#
# self.tile_dir: ../data/triplets/49anchor.npy
#
# self.tile_dir: ../data/triplets/428anchor.npy
#
# self.tile_dir: ../data/triplets/293anchor.npy
#
# self.tile_dir: ../data/triplets/444anchor.npy
#
# self.tile_dir: ../data/triplets/494anchor.npy
#
# self.tile_dir: ../data/triplets/245anchor.npy
#
# self.tile_dir: ../data/triplets/22anchor.npy
#
# self.tile_dir: ../data/triplets/446anchor.npy
#
# self.tile_dir: ../data/triplets/11anchor.npy
#
# self.tile_dir: ../data/triplets/50anchor.npy
#
# self.tile_dir: ../data/triplets/382anchor.npy
# self.tile_dir: ../data/triplets/172anchor.npy
#
#
# self.tile_dir: ../data/triplets/467anchor.npy
# self.tile_dir: ../data/triplets/141anchor.npy
#
#
# self.tile_dir: ../data/triplets/158anchor.npy
# self.tile_dir: ../data/triplets/410anchor.npy
#
#
# self.tile_dir: ../data/triplets/210anchor.npy
# self.tile_dir: ../data/triplets/376anchor.npy
#
#
# self.tile_dir: ../data/triplets/313anchor.npy
# self.tile_dir: ../data/triplets/368anchor.npy
#
#
# self.tile_dir: ../data/triplets/466anchor.npy
#
# self.tile_dir: ../data/triplets/204anchor.npy
#
# self.tile_dir: ../data/triplets/443anchor.npy
#
# self.tile_dir: ../data/triplets/124anchor.npy
#
# self.tile_dir: ../data/triplets/363anchor.npy
#
# self.tile_dir: ../data/triplets/100anchor.npy
#
# self.tile_dir: ../data/triplets/457anchor.npy
#
# self.tile_dir: ../data/triplets/418anchor.npy
#
# self.tile_dir: ../data/triplets/289anchor.npy
#
# self.tile_dir: ../data/triplets/78anchor.npy
#
# self.tile_dir: ../data/triplets/239anchor.npy
#
# self.tile_dir: ../data/triplets/79anchor.npy
#
# self.tile_dir: ../data/triplets/98anchor.npy
#
# self.tile_dir: ../data/triplets/252anchor.npy
#
# self.tile_dir: ../data/triplets/384anchor.npy
#
# self.tile_dir: ../data/triplets/243anchor.npy
# self.tile_dir: ../data/triplets/366anchor.npy
#
#
# self.tile_dir: ../data/triplets/30anchor.npy
# self.tile_dir: ../data/triplets/481anchor.npy
#
#
# self.tile_dir: ../data/triplets/84anchor.npy
# self.tile_dir: ../data/triplets/412anchor.npy
#
#
# self.tile_dir: ../data/triplets/166anchor.npy
# self.tile_dir: ../data/triplets/190anchor.npy
#
#
# self.tile_dir: ../data/triplets/403anchor.npy
# self.tile_dir: ../data/triplets/167anchor.npy
#
#
# self.tile_dir: ../data/triplets/246anchor.npy
# self.tile_dir: ../data/triplets/194anchor.npy
#
#
# self.tile_dir: ../data/triplets/230anchor.npy
# self.tile_dir: ../data/triplets/150anchor.npy
#
#
# self.tile_dir: ../data/triplets/385anchor.npy
#
# self.tile_dir: ../data/triplets/233anchor.npy
#
# self.tile_dir: ../data/triplets/425anchor.npy
#
# self.tile_dir: ../data/triplets/315anchor.npy
#
# self.tile_dir: ../data/triplets/283anchor.npy
#
# self.tile_dir: ../data/triplets/338anchor.npy
#
# self.tile_dir: ../data/triplets/266anchor.npy
#
# self.tile_dir: ../data/triplets/327anchor.npy
#
# self.tile_dir: ../data/triplets/226anchor.npy
#
# self.tile_dir: ../data/triplets/358anchor.npy
# self.tile_dir: ../data/triplets/18anchor.npy
#
#
# self.tile_dir: ../data/triplets/119anchor.npy
#
# self.tile_dir: ../data/triplets/93anchor.npy
#
# self.tile_dir: ../data/triplets/330anchor.npy
#
# self.tile_dir: ../data/triplets/353anchor.npy
#
# self.tile_dir: ../data/triplets/14anchor.npy
#
# self.tile_dir: ../data/triplets/292anchor.npy
# self.tile_dir: ../data/triplets/37anchor.npy
#
#
# self.tile_dir: ../data/triplets/499anchor.npy
#
# self.tile_dir: ../data/triplets/81anchor.npy
#
# self.tile_dir: ../data/triplets/422anchor.npy
#
# self.tile_dir: ../data/triplets/260anchor.npy
#
# self.tile_dir: ../data/triplets/254anchor.npy
#
# self.tile_dir: ../data/triplets/173anchor.npy
# self.tile_dir: ../data/triplets/92anchor.npy
#
#
# self.tile_dir: ../data/triplets/138anchor.npy
#
# self.tile_dir: ../data/triplets/106anchor.npy
#
# self.tile_dir: ../data/triplets/361anchor.npy
#
# self.tile_dir: ../data/triplets/335anchor.npy
#
# self.tile_dir: ../data/triplets/280anchor.npy
#
# self.tile_dir: ../data/triplets/120anchor.npy
#
# self.tile_dir: ../data/triplets/75anchor.npy
#
# self.tile_dir: ../data/triplets/112anchor.npy
#
# self.tile_dir: ../data/triplets/15anchor.npy
#
# self.tile_dir: ../data/triplets/179anchor.npy
#
# self.tile_dir: ../data/triplets/281anchor.npy
#
# self.tile_dir: ../data/triplets/72anchor.npy
#
# self.tile_dir: ../data/triplets/288anchor.npy
#
# self.tile_dir: ../data/triplets/189anchor.npy
#
# self.tile_dir: ../data/triplets/496anchor.npy
#
# Finished epoch 2: 7.946s
#   Average loss: 6.1368
#   Average l_n: 3.6758
#   Average l_d: -13.7730
#   Average l_nd: -10.0972
#
# self.tile_dir: ../data/triplets/257anchor.npy
#
# self.tile_dir: ../data/triplets/454anchor.npy
#
# self.tile_dir: ../data/triplets/128anchor.npy
#
# self.tile_dir: ../data/triplets/64anchor.npy
#
# self.tile_dir: ../data/triplets/93anchor.npy
# self.tile_dir: ../data/triplets/319anchor.npy
#
#
# self.tile_dir: ../data/triplets/29anchor.npy
# self.tile_dir: ../data/triplets/52anchor.npy
#
#
# self.tile_dir: ../data/triplets/182anchor.npy
#
# self.tile_dir: ../data/triplets/366anchor.npy
# self.tile_dir: ../data/triplets/368anchor.npy
#
#
# self.tile_dir: ../data/triplets/328anchor.npy
# self.tile_dir: ../data/triplets/480anchor.npy
# self.tile_dir: ../data/triplets/123anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/38anchor.npy
# self.tile_dir: ../data/triplets/265anchor.npy
# self.tile_dir: ../data/triplets/133anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/191anchor.npy
# self.tile_dir: ../data/triplets/125anchor.npy
# self.tile_dir: ../data/triplets/183anchor.npy
#
#
#
# ...
#
#
# self.tile_dir: ../data/triplets/357anchor.npy
# self.tile_dir: ../data/triplets/427anchor.npy
#
#
# self.tile_dir: ../data/triplets/145anchor.npy
# self.tile_dir: ../data/triplets/301anchor.npy
#
#
# self.tile_dir: ../data/triplets/318anchor.npy
# self.tile_dir: ../data/triplets/185anchor.npy
#
#
# self.tile_dir: ../data/triplets/68anchor.npy
# self.tile_dir: ../data/triplets/125anchor.npy
#
#
# self.tile_dir: ../data/triplets/89anchor.npy
# self.tile_dir: ../data/triplets/358anchor.npy
#
#
# self.tile_dir: ../data/triplets/354anchor.npy
# self.tile_dir: ../data/triplets/228anchor.npy
#
#
# self.tile_dir: ../data/triplets/59anchor.npy
# self.tile_dir: ../data/triplets/219anchor.npy
#
#
# self.tile_dir: ../data/triplets/5anchor.npy
# self.tile_dir: ../data/triplets/291anchor.npy
#
#
# self.tile_dir: ../data/triplets/165anchor.npy
# self.tile_dir: ../data/triplets/451anchor.npy
#
#
# self.tile_dir: ../data/triplets/163anchor.npy
#
# self.tile_dir: ../data/triplets/213anchor.npy
# self.tile_dir: ../data/triplets/280anchor.npy
#
#
# self.tile_dir: ../data/triplets/465anchor.npy
# self.tile_dir: ../data/triplets/30anchor.npy
# self.tile_dir: ../data/triplets/385anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/359anchor.npy
# self.tile_dir: ../data/triplets/182anchor.npy
# self.tile_dir: ../data/triplets/8anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/218anchor.npy
# self.tile_dir: ../data/triplets/207anchor.npy
# self.tile_dir: ../data/triplets/111anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/172anchor.npy
# self.tile_dir: ../data/triplets/409anchor.npy
# self.tile_dir: ../data/triplets/53anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/391anchor.npy
# self.tile_dir: ../data/triplets/123anchor.npy
#
# self.tile_dir: ../data/triplets/407anchor.npy
#
#
# self.tile_dir: ../data/triplets/421anchor.npy
# self.tile_dir: ../data/triplets/255anchor.npy
#
# self.tile_dir: ../data/triplets/444anchor.npy
#
#
# self.tile_dir: ../data/triplets/327anchor.npy
# self.tile_dir: ../data/triplets/94anchor.npy
#
#
# self.tile_dir: ../data/triplets/12anchor.npy
#
# self.tile_dir: ../data/triplets/38anchor.npy
#
# self.tile_dir: ../data/triplets/459anchor.npy
# self.tile_dir: ../data/triplets/346anchor.npy
#
#
# self.tile_dir: ../data/triplets/24anchor.npy
#
# self.tile_dir: ../data/triplets/263anchor.npy
#
# self.tile_dir: ../data/triplets/48anchor.npy
#
# self.tile_dir: ../data/triplets/496anchor.npy
#
# self.tile_dir: ../data/triplets/164anchor.npy
#
# self.tile_dir: ../data/triplets/322anchor.npy
#
# self.tile_dir: ../data/triplets/445anchor.npy
#
# self.tile_dir: ../data/triplets/442anchor.npy
#
# self.tile_dir: ../data/triplets/150anchor.npy
# self.tile_dir: ../data/triplets/103anchor.npy
#
#
# self.tile_dir: ../data/triplets/194anchor.npy
#
# self.tile_dir: ../data/triplets/247anchor.npy
# self.tile_dir: ../data/triplets/472anchor.npy
#
#
# self.tile_dir: ../data/triplets/240anchor.npy
#
# self.tile_dir: ../data/triplets/113anchor.npy
# self.tile_dir: ../data/triplets/342anchor.npy
#
#
# self.tile_dir: ../data/triplets/305anchor.npy
#
# self.tile_dir: ../data/triplets/33anchor.npy
# self.tile_dir: ../data/triplets/495anchor.npy
#
#
# self.tile_dir: ../data/triplets/230anchor.npy
#
# self.tile_dir: ../data/triplets/251anchor.npy
# self.tile_dir: ../data/triplets/101anchor.npy
#
#
# self.tile_dir: ../data/triplets/132anchor.npy
#
# self.tile_dir: ../data/triplets/439anchor.npy
# self.tile_dir: ../data/triplets/364anchor.npy
#
#
# self.tile_dir: ../data/triplets/41anchor.npy
#
# self.tile_dir: ../data/triplets/126anchor.npy
#
# self.tile_dir: ../data/triplets/398anchor.npy
# self.tile_dir: ../data/triplets/173anchor.npy
#
#
# self.tile_dir: ../data/triplets/157anchor.npy
#
# self.tile_dir: ../data/triplets/254anchor.npy
#
# self.tile_dir: ../data/triplets/105anchor.npy
#
# self.tile_dir: ../data/triplets/365anchor.npy
#
# self.tile_dir: ../data/triplets/159anchor.npy
#
# self.tile_dir: ../data/triplets/447anchor.npy
#
# self.tile_dir: ../data/triplets/317anchor.npy
#
# self.tile_dir: ../data/triplets/383anchor.npy
#
# self.tile_dir: ../data/triplets/115anchor.npy
#
# self.tile_dir: ../data/triplets/474anchor.npy
#
# self.tile_dir: ../data/triplets/320anchor.npy
# self.tile_dir: ../data/triplets/97anchor.npy
#
# self.tile_dir: ../data/triplets/468anchor.npy
#
#
# self.tile_dir: ../data/triplets/331anchor.npy
#
# self.tile_dir: ../data/triplets/77anchor.npy
# self.tile_dir: ../data/triplets/464anchor.npy
#
#
# self.tile_dir: ../data/triplets/370anchor.npy
#
# self.tile_dir: ../data/triplets/341anchor.npy
# self.tile_dir: ../data/triplets/380anchor.npy
#
#
# self.tile_dir: ../data/triplets/175anchor.npy
#
# self.tile_dir: ../data/triplets/223anchor.npy
#
# self.tile_dir: ../data/triplets/229anchor.npy
# self.tile_dir: ../data/triplets/328anchor.npy
#
#
# self.tile_dir: ../data/triplets/281anchor.npy
#
# self.tile_dir: ../data/triplets/252anchor.npy
# self.tile_dir: ../data/triplets/334anchor.npy
#
#
# self.tile_dir: ../data/triplets/395anchor.npy
#
# self.tile_dir: ../data/triplets/0anchor.npy
# self.tile_dir: ../data/triplets/66anchor.npy
#
#
# self.tile_dir: ../data/triplets/491anchor.npy
#
# self.tile_dir: ../data/triplets/36anchor.npy
# self.tile_dir: ../data/triplets/486anchor.npy
#
#
# self.tile_dir: ../data/triplets/242anchor.npy
#
# self.tile_dir: ../data/triplets/392anchor.npy
# self.tile_dir: ../data/triplets/298anchor.npy
#
# self.tile_dir: ../data/triplets/473anchor.npy
#
#
# self.tile_dir: ../data/triplets/488anchor.npy
# self.tile_dir: ../data/triplets/483anchor.npy
#
#
# self.tile_dir: ../data/triplets/415anchor.npy
#
# self.tile_dir: ../data/triplets/289anchor.npy
# self.tile_dir: ../data/triplets/205anchor.npy
#
#
# self.tile_dir: ../data/triplets/283anchor.npy
#
# self.tile_dir: ../data/triplets/23anchor.npy
#
# self.tile_dir: ../data/triplets/129anchor.npy
#
# self.tile_dir: ../data/triplets/294anchor.npy
#
# self.tile_dir: ../data/triplets/70anchor.npy
#
# self.tile_dir: ../data/triplets/429anchor.npy
#
# self.tile_dir: ../data/triplets/456anchor.npy
#
# self.tile_dir: ../data/triplets/335anchor.npy
#
# self.tile_dir: ../data/triplets/360anchor.npy
#
# self.tile_dir: ../data/triplets/114anchor.npy
#
# self.tile_dir: ../data/triplets/460anchor.npy
#
# self.tile_dir: ../data/triplets/26anchor.npy
#
# self.tile_dir: ../data/triplets/462anchor.npy
#
# self.tile_dir: ../data/triplets/419anchor.npy
#
# self.tile_dir: ../data/triplets/405anchor.npy
#
# self.tile_dir: ../data/triplets/78anchor.npy
#
# self.tile_dir: ../data/triplets/231anchor.npy
#
# self.tile_dir: ../data/triplets/232anchor.npy
#
# self.tile_dir: ../data/triplets/90anchor.npy
#
# self.tile_dir: ../data/triplets/413anchor.npy
#
# self.tile_dir: ../data/triplets/386anchor.npy
# self.tile_dir: ../data/triplets/480anchor.npy
#
#
# self.tile_dir: ../data/triplets/312anchor.npy
# self.tile_dir: ../data/triplets/106anchor.npy
# self.tile_dir: ../data/triplets/136anchor.npy
#
#
#
# self.tile_dir: ../data/triplets/489anchor.npy
# self.tile_dir: ../data/triplets/382anchor.npy
#
#
# self.tile_dir: ../data/triplets/497anchor.npy
#
# self.tile_dir: ../data/triplets/210anchor.npy
# self.tile_dir: ../data/triplets/144anchor.npy
#
#
# self.tile_dir: ../data/triplets/403anchor.npy
#
# self.tile_dir: ../data/triplets/302anchor.npy
#
# self.tile_dir: ../data/triplets/204anchor.npy
#
# self.tile_dir: ../data/triplets/40anchor.npy
#
# self.tile_dir: ../data/triplets/64anchor.npy
# self.tile_dir: ../data/triplets/336anchor.npy
#
#
# self.tile_dir: ../data/triplets/43anchor.npy
# self.tile_dir: ../data/triplets/162anchor.npy
#
#
# self.tile_dir: ../data/triplets/215anchor.npy
#
# self.tile_dir: ../data/triplets/9anchor.npy
#
# self.tile_dir: ../data/triplets/479anchor.npy
#
# self.tile_dir: ../data/triplets/71anchor.npy
#
# self.tile_dir: ../data/triplets/135anchor.npy
#
# self.tile_dir: ../data/triplets/85anchor.npy
#
# self.tile_dir: ../data/triplets/107anchor.npy
#
# self.tile_dir: ../data/triplets/87anchor.npy
#
# self.tile_dir: ../data/triplets/83anchor.npy
#
# self.tile_dir: ../data/triplets/238anchor.npy
#
# self.tile_dir: ../data/triplets/55anchor.npy
#
# self.tile_dir: ../data/triplets/375anchor.npy
#
# self.tile_dir: ../data/triplets/373anchor.npy
#
# self.tile_dir: ../data/triplets/448anchor.npy
# self.tile_dir: ../data/triplets/222anchor.npy
#
#
# self.tile_dir: ../data/triplets/296anchor.npy
# self.tile_dir: ../data/triplets/2anchor.npy
#
#
# self.tile_dir: ../data/triplets/315anchor.npy
# self.tile_dir: ../data/triplets/261anchor.npy
#
#
# self.tile_dir: ../data/triplets/433anchor.npy
#
# self.tile_dir: ../data/triplets/244anchor.npy
#
# self.tile_dir: ../data/triplets/133anchor.npy
#
# self.tile_dir: ../data/triplets/492anchor.npy
# self.tile_dir: ../data/triplets/181anchor.npy
#
#
# self.tile_dir: ../data/triplets/234anchor.npy
# self.tile_dir: ../data/triplets/209anchor.npy
#
#
# self.tile_dir: ../data/triplets/73anchor.npy
# self.tile_dir: ../data/triplets/266anchor.npy
#
# self.tile_dir: ../data/triplets/286anchor.npy
#
#
# self.tile_dir: ../data/triplets/110anchor.npy
#
# self.tile_dir: ../data/triplets/384anchor.npy
#
# self.tile_dir: ../data/triplets/490anchor.npy
#
# self.tile_dir: ../data/triplets/441anchor.npy
#
# self.tile_dir: ../data/triplets/499anchor.npy
#
# self.tile_dir: ../data/triplets/449anchor.npy
#
# self.tile_dir: ../data/triplets/457anchor.npy
#
# self.tile_dir: ../data/triplets/270anchor.npy
#
# self.tile_dir: ../data/triplets/11anchor.npy
#
# self.tile_dir: ../data/triplets/350anchor.npy
#
# self.tile_dir: ../data/triplets/316anchor.npy
#
# self.tile_dir: ../data/triplets/277anchor.npy
#
# self.tile_dir: ../data/triplets/326anchor.npy
#
# self.tile_dir: ../data/triplets/44anchor.npy
#
# self.tile_dir: ../data/triplets/188anchor.npy
#
# self.tile_dir: ../data/triplets/310anchor.npy
#
# self.tile_dir: ../data/triplets/374anchor.npy
#
# self.tile_dir: ../data/triplets/347anchor.npy
#
# self.tile_dir: ../data/triplets/143anchor.npy
#
# self.tile_dir: ../data/triplets/454anchor.npy
#
# self.tile_dir: ../data/triplets/112anchor.npy
#
# self.tile_dir: ../data/triplets/25anchor.npy
#
# self.tile_dir: ../data/triplets/109anchor.npy
#
# self.tile_dir: ../data/triplets/4anchor.npy
#
# self.tile_dir: ../data/triplets/424anchor.npy
#
# self.tile_dir: ../data/triplets/158anchor.npy
#
# self.tile_dir: ../data/triplets/416anchor.npy
# self.tile_dir: ../data/triplets/367anchor.npy
#
#
# self.tile_dir: ../data/triplets/131anchor.npy
# self.tile_dir: ../data/triplets/180anchor.npy
#
#
# self.tile_dir: ../data/triplets/324anchor.npy
# self.tile_dir: ../data/triplets/184anchor.npy
#
#
# self.tile_dir: ../data/triplets/400anchor.npy
# self.tile_dir: ../data/triplets/443anchor.npy
#
#
# self.tile_dir: ../data/triplets/325anchor.npy
# self.tile_dir: ../data/triplets/308anchor.npy
#
#
# self.tile_dir: ../data/triplets/368anchor.npy
# self.tile_dir: ../data/triplets/267anchor.npy
#
# self.tile_dir: ../data/triplets/498anchor.npy
#
# self.tile_dir: ../data/triplets/20anchor.npy
#
# self.tile_dir: ../data/triplets/484anchor.npy
#
# self.tile_dir: ../data/triplets/475anchor.npy
#
# self.tile_dir: ../data/triplets/431anchor.npy
#
#
# self.tile_dir: ../data/triplets/183anchor.npy
#
# self.tile_dir: ../data/triplets/494anchor.npy
#
# self.tile_dir: ../data/triplets/199anchor.npy
#
# self.tile_dir: ../data/triplets/39anchor.npy
#
# self.tile_dir: ../data/triplets/217anchor.npy
#
# self.tile_dir: ../data/triplets/178anchor.npy
#
# self.tile_dir: ../data/triplets/86anchor.npy
#
# self.tile_dir: ../data/triplets/248anchor.npy
#
# self.tile_dir: ../data/triplets/422anchor.npy
#
# self.tile_dir: ../data/triplets/493anchor.npy
#
# self.tile_dir: ../data/triplets/45anchor.npy
#
# self.tile_dir: ../data/triplets/279anchor.npy
#
# self.tile_dir: ../data/triplets/333anchor.npy
#
# self.tile_dir: ../data/triplets/319anchor.npy
#
# self.tile_dir: ../data/triplets/311anchor.npy
#
# self.tile_dir: ../data/triplets/54anchor.npy
#
# self.tile_dir: ../data/triplets/256anchor.npy
#
# self.tile_dir: ../data/triplets/18anchor.npy
#
# self.tile_dir: ../data/triplets/377anchor.npy
#
# self.tile_dir: ../data/triplets/51anchor.npy
#
# self.tile_dir: ../data/triplets/196anchor.npy
#
# self.tile_dir: ../data/triplets/410anchor.npy
#
# self.tile_dir: ../data/triplets/412anchor.npy
#
# self.tile_dir: ../data/triplets/119anchor.npy
#
# self.tile_dir: ../data/triplets/470anchor.npy
#
# self.tile_dir: ../data/triplets/288anchor.npy
#
# self.tile_dir: ../data/triplets/420anchor.npy
#
# self.tile_dir: ../data/triplets/69anchor.npy
#
# self.tile_dir: ../data/triplets/193anchor.npy
#
# self.tile_dir: ../data/triplets/179anchor.npy
#
# self.tile_dir: ../data/triplets/13anchor.npy
#
# self.tile_dir: ../data/triplets/455anchor.npy
#
# self.tile_dir: ../data/triplets/330anchor.npy
#
# self.tile_dir: ../data/triplets/29anchor.npy
#
# self.tile_dir: ../data/triplets/469anchor.npy
#
# self.tile_dir: ../data/triplets/426anchor.npy
#
# self.tile_dir: ../data/triplets/98anchor.npy
#
# self.tile_dir: ../data/triplets/250anchor.npy
#
# self.tile_dir: ../data/triplets/418anchor.npy
#
# self.tile_dir: ../data/triplets/349anchor.npy
#
# self.tile_dir: ../data/triplets/337anchor.npy
#
# self.tile_dir: ../data/triplets/156anchor.npy
#
# self.tile_dir: ../data/triplets/482anchor.npy
#
# self.tile_dir: ../data/triplets/146anchor.npy
#
# self.tile_dir: ../data/triplets/176anchor.npy
#
# self.tile_dir: ../data/triplets/396anchor.npy
#
# self.tile_dir: ../data/triplets/432anchor.npy
#
# self.tile_dir: ../data/triplets/299anchor.npy
#
# self.tile_dir: ../data/triplets/245anchor.npy
#
# self.tile_dir: ../data/triplets/96anchor.npy
#
# self.tile_dir: ../data/triplets/485anchor.npy
#
# self.tile_dir: ../data/triplets/220anchor.npy
#
# self.tile_dir: ../data/triplets/116anchor.npy
#
# self.tile_dir: ../data/triplets/211anchor.npy
#
# self.tile_dir: ../data/triplets/190anchor.npy
#
# self.tile_dir: ../data/triplets/393anchor.npy
#
# self.tile_dir: ../data/triplets/273anchor.npy
#
# self.tile_dir: ../data/triplets/428anchor.npy
#
# self.tile_dir: ../data/triplets/309anchor.npy
#
# self.tile_dir: ../data/triplets/226anchor.npy
#
# self.tile_dir: ../data/triplets/117anchor.npy
#
# self.tile_dir: ../data/triplets/402anchor.npy
#
# self.tile_dir: ../data/triplets/139anchor.npy
#
# self.tile_dir: ../data/triplets/130anchor.npy
#
# self.tile_dir: ../data/triplets/236anchor.npy
#
# self.tile_dir: ../data/triplets/440anchor.npy
#
# self.tile_dir: ../data/triplets/414anchor.npy
#
# self.tile_dir: ../data/triplets/141anchor.npy
#
# self.tile_dir: ../data/triplets/118anchor.npy
#
# self.tile_dir: ../data/triplets/378anchor.npy
#
# self.tile_dir: ../data/triplets/297anchor.npy
#
# self.tile_dir: ../data/triplets/284anchor.npy
#
# self.tile_dir: ../data/triplets/46anchor.npy
#
# self.tile_dir: ../data/triplets/155anchor.npy
#
# self.tile_dir: ../data/triplets/124anchor.npy
#
# self.tile_dir: ../data/triplets/404anchor.npy
#
# self.tile_dir: ../data/triplets/84anchor.npy
#
# self.tile_dir: ../data/triplets/376anchor.npy
#
# self.tile_dir: ../data/triplets/275anchor.npy
#
# self.tile_dir: ../data/triplets/343anchor.npy
#
# self.tile_dir: ../data/triplets/237anchor.npy
#
# self.tile_dir: ../data/triplets/138anchor.npy
#
# self.tile_dir: ../data/triplets/366anchor.npy
#
# self.tile_dir: ../data/triplets/6anchor.npy
#
# self.tile_dir: ../data/triplets/246anchor.npy
#
# self.tile_dir: ../data/triplets/17anchor.npy
#
# self.tile_dir: ../data/triplets/458anchor.npy
#
# self.tile_dir: ../data/triplets/390anchor.npy
#
# self.tile_dir: ../data/triplets/102anchor.npy
#
# self.tile_dir: ../data/triplets/268anchor.npy
#
# self.tile_dir: ../data/triplets/35anchor.npy
#
# self.tile_dir: ../data/triplets/272anchor.npy
#
# self.tile_dir: ../data/triplets/88anchor.npy
#
# self.tile_dir: ../data/triplets/446anchor.npy
#
# self.tile_dir: ../data/triplets/1anchor.npy
#
# self.tile_dir: ../data/triplets/348anchor.npy
#
# self.tile_dir: ../data/triplets/321anchor.npy
#
# self.tile_dir: ../data/triplets/50anchor.npy
#
# self.tile_dir: ../data/triplets/168anchor.npy
#
# self.tile_dir: ../data/triplets/399anchor.npy
#
# self.tile_dir: ../data/triplets/198anchor.npy
#
# self.tile_dir: ../data/triplets/214anchor.npy
#
# self.tile_dir: ../data/triplets/463anchor.npy
#
# self.tile_dir: ../data/triplets/161anchor.npy
#
# self.tile_dir: ../data/triplets/417anchor.npy
#
# self.tile_dir: ../data/triplets/72anchor.npy
#
# self.tile_dir: ../data/triplets/394anchor.npy
#
# self.tile_dir: ../data/triplets/167anchor.npy
#
# self.tile_dir: ../data/triplets/192anchor.npy
#
# self.tile_dir: ../data/triplets/95anchor.npy
#
# self.tile_dir: ../data/triplets/154anchor.npy
#
# self.tile_dir: ../data/triplets/355anchor.npy
#
# self.tile_dir: ../data/triplets/351anchor.npy
#
# self.tile_dir: ../data/triplets/466anchor.npy
#
# Finished epoch 50: 158.266s
#   Average loss: 3.3634
#   Average l_n: 2.0133
#   Average l_d: -12.4201
#   Average l_nd: -10.4067
