# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from src.sample_tiles import get_triplet_imgs, get_triplet_tiles

import torch
from torch import optim
from time import time

from src.datasets import TileTripletsDataset, GetBands, RandomFlipAndRotate, ClipAndScale, ToFloatTensor, triplet_dataloader
from src.tilenet import make_tilenet
from src.training import prep_triplets, train_triplet_epoch

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 10
#       7 from torch import optim
#       8 from time import time
# ---> 10 from src.datasets import TileTripletsDataset, GetBands, RandomFlipAndRotate, ClipAndScale, ToFloatTensor, triplet_dataloader
#      11 from src.tilenet import make_tilenet
#      12 from src.training import prep_triplets, train_triplet_epoch
#
# File /volume/home/lukasz/WB_projekt/code/src/datasets.py:7
#       5 import os
#       6 import numpy as np
# ----> 7 from src.data_utils import clip_and_scale_image
#      10 class TileTripletsDataset(Dataset):
#      12     def __init__(self, tile_dir, transform=None, n_triplets=None,
#      13         pairs_only=True):
#
# File /volume/home/lukasz/WB_projekt/code/src/data_utils.py:2
#       1 import os
# ----> 2 import gdal
#       3 import imageio
#       4 from time import time
#
# ModuleNotFoundError: No module named 'gdal'

# %% [markdown]
# # Prepare tiles

# %%
img_dir_list = [x[0] for x in os.walk("/storage/EuroSATallBands/")][1:]
tile_dir = '../data/triplets' # where you want to save your tiles

for img_dir in img_dir_list: 
    print(f"Current dir: {dir}")
    img_triplets = get_triplet_imgs(img_dir, ".tif", n_triplets=10)
    print(img_triplets[:5,:])

    tiles = get_triplet_tiles(tile_dir,
                          img_dir, 
                          img_triplets, 
                          tile_size=64,
                          val_type='float32',
                          bands_only=True,
                          save=True,
                          verbose=True)
# Out:
# Current dir: /storage/EuroSATallBands/SeaLake
# [['AnnualCrop_1852.tif' 'AnnualCrop_1876.tif']
#  ['AnnualCrop_2660.tif' 'AnnualCrop_2129.tif']
#  ['AnnualCrop_2763.tif' 'AnnualCrop_2685.tif']
#  ['AnnualCrop_1109.tif' 'AnnualCrop_1567.tif']
#  ['AnnualCrop_42.tif' 'AnnualCrop_243.tif']]
# Sampling image AnnualCrop_1109.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(72, 95)
#     Neighbor tile center:(77, 53)
# Sampling image AnnualCrop_1567.tif from dir
#     Saving distant tile #3
#     Distant tile center:(78, 94)
# Sampling image AnnualCrop_1633.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(41, 84)
#     Neighbor tile center:(76, 72)
# Sampling image AnnualCrop_1657.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(86, 65)
#     Neighbor tile center:(34, 89)
# Sampling image AnnualCrop_1852.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(41, 47)
#     Neighbor tile center:(91, 92)
# Sampling image AnnualCrop_1876.tif from dir
#     Saving distant tile #0
#     Distant tile center:(89, 61)
# Sampling image AnnualCrop_2129.tif from dir
#     Saving distant tile #1
#     Distant tile center:(35, 62)
# Sampling image AnnualCrop_2255.tif from dir
#     Saving distant tile #9
#     Distant tile center:(61, 47)
# Sampling image AnnualCrop_2287.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(92, 67)
#     Neighbor tile center:(48, 87)
# Sampling image AnnualCrop_243.tif from dir
#     Saving distant tile #4
#     Distant tile center:(80, 78)
# Sampling image AnnualCrop_2585.tif from dir
#     Saving distant tile #8
#     Distant tile center:(74, 53)
# Sampling image AnnualCrop_26.tif from dir
#     Saving distant tile #7
#     Distant tile center:(79, 49)
# Sampling image AnnualCrop_2660.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(47, 60)
#     Neighbor tile center:(95, 74)
# Sampling image AnnualCrop_2685.tif from dir
#     Saving distant tile #2
#     Distant tile center:(49, 89)
# Sampling image AnnualCrop_2763.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(80, 46)
#     Neighbor tile center:(88, 65)
# Sampling image AnnualCrop_283.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(66, 64)
#     Neighbor tile center:(91, 46)
# Sampling image AnnualCrop_2961.tif from dir
#     Saving distant tile #6
#     Distant tile center:(37, 64)
# Sampling image AnnualCrop_42.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(50, 52)
#     Neighbor tile center:(91, 68)
# Sampling image AnnualCrop_66.tif from dir
#     Saving distant tile #5
#     Distant tile center:(32, 53)
# Sampling image AnnualCrop_831.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(35, 32)
#     Neighbor tile center:(92, 90)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['Highway_2348.tif' 'Highway_209.tif']
#  ['Highway_1716.tif' 'Highway_2049.tif']
#  ['Highway_2476.tif' 'Highway_1676.tif']
#  ['Highway_175.tif' 'Highway_168.tif']
#  ['Highway_476.tif' 'Highway_1327.tif']]
# Sampling image Highway_1230.tif from dir
#     Saving distant tile #6
#     Distant tile center:(72, 49)
# Sampling image Highway_1302.tif from dir
#     Saving distant tile #5
#     Distant tile center:(59, 52)
# Sampling image Highway_1323.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(84, 80)
#     Neighbor tile center:(72, 57)
# Sampling image Highway_1327.tif from dir
#     Saving distant tile #4
#     Distant tile center:(34, 55)
# Sampling image Highway_1561.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(45, 80)
#     Neighbor tile center:(64, 80)
# Sampling image Highway_1676.tif from dir
#     Saving distant tile #2
#     Distant tile center:(66, 39)
# Sampling image Highway_168.tif from dir
#     Saving distant tile #3
#     Distant tile center:(87, 80)
# Sampling image Highway_1716.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(55, 74)
#     Neighbor tile center:(50, 91)
# Sampling image Highway_175.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(94, 83)
#     Neighbor tile center:(75, 53)
# Sampling image Highway_1806.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(87, 83)
#     Neighbor tile center:(79, 85)
# Sampling image Highway_1836.tif from dir
#     Saving distant tile #9
#     Distant tile center:(74, 79)
# Sampling image Highway_2049.tif from dir
#     Saving distant tile #1
#     Distant tile center:(61, 94)
# Sampling image Highway_209.tif from dir
#     Saving distant tile #0
#     Distant tile center:(89, 38)
# Sampling image Highway_2256.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(64, 55)
#     Neighbor tile center:(83, 89)
# Sampling image Highway_2281.tif from dir
#     Saving distant tile #7
#     Distant tile center:(54, 90)
# Sampling image Highway_2341.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(86, 90)
#     Neighbor tile center:(82, 41)
# Sampling image Highway_2348.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(51, 80)
#     Neighbor tile center:(53, 71)
# Sampling image Highway_2476.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(84, 64)
#     Neighbor tile center:(76, 68)
# Sampling image Highway_476.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(54, 59)
#     Neighbor tile center:(93, 57)
# Sampling image Highway_833.tif from dir
#     Saving distant tile #8
#     Distant tile center:(82, 54)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['HerbaceousVegetation_2754.tif' 'HerbaceousVegetation_965.tif']
#  ['HerbaceousVegetation_1833.tif' 'HerbaceousVegetation_1600.tif']
#  ['HerbaceousVegetation_538.tif' 'HerbaceousVegetation_279.tif']
#  ['HerbaceousVegetation_1103.tif' 'HerbaceousVegetation_1588.tif']
#  ['HerbaceousVegetation_2404.tif' 'HerbaceousVegetation_1055.tif']]
# Sampling image HerbaceousVegetation_1055.tif from dir
#     Saving distant tile #4
#     Distant tile center:(73, 57)
# Sampling image HerbaceousVegetation_1084.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(87, 35)
#     Neighbor tile center:(74, 90)
# Sampling image HerbaceousVegetation_1103.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(42, 67)
#     Neighbor tile center:(88, 56)
# Sampling image HerbaceousVegetation_1468.tif from dir
#     Saving distant tile #7
#     Distant tile center:(50, 85)
# Sampling image HerbaceousVegetation_1588.tif from dir
#     Saving distant tile #3
#     Distant tile center:(73, 90)
# Sampling image HerbaceousVegetation_1600.tif from dir
#     Saving distant tile #1
#     Distant tile center:(62, 64)
# Sampling image HerbaceousVegetation_1677.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(92, 88)
#     Neighbor tile center:(58, 68)
# Sampling image HerbaceousVegetation_1833.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(75, 83)
#     Neighbor tile center:(78, 76)
# Sampling image HerbaceousVegetation_1953.tif from dir
#     Saving distant tile #8
#     Distant tile center:(61, 95)
# Sampling image HerbaceousVegetation_2153.tif from dir
#     Saving distant tile #6
#     Distant tile center:(33, 83)
# Sampling image HerbaceousVegetation_2249.tif from dir
#     Saving distant tile #9
#     Distant tile center:(57, 88)
# Sampling image HerbaceousVegetation_2404.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(74, 63)
#     Neighbor tile center:(90, 63)
# Sampling image HerbaceousVegetation_2628.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(33, 45)
#     Neighbor tile center:(88, 64)
# Sampling image HerbaceousVegetation_2650.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(40, 65)
#     Neighbor tile center:(80, 92)
# Sampling image HerbaceousVegetation_2754.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(67, 41)
#     Neighbor tile center:(48, 85)
# Sampling image HerbaceousVegetation_2784.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(71, 62)
#     Neighbor tile center:(69, 43)
# Sampling image HerbaceousVegetation_279.tif from dir
#     Saving distant tile #2
#     Distant tile center:(56, 68)
# Sampling image HerbaceousVegetation_2945.tif from dir
#     Saving distant tile #5
#     Distant tile center:(43, 74)
# Sampling image HerbaceousVegetation_538.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(82, 41)
#     Neighbor tile center:(55, 49)
# Sampling image HerbaceousVegetation_965.tif from dir
#     Saving distant tile #0
#     Distant tile center:(32, 55)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['Industrial_385.tif' 'Industrial_259.tif']
#  ['Industrial_2261.tif' 'Industrial_1994.tif']
#  ['Industrial_1758.tif' 'Industrial_1527.tif']
#  ['Industrial_1716.tif' 'Industrial_517.tif']
#  ['Industrial_654.tif' 'Industrial_1902.tif']]
# Sampling image Industrial_104.tif from dir
#     Saving distant tile #8
#     Distant tile center:(50, 54)
# Sampling image Industrial_1093.tif from dir
#     Saving distant tile #9
#     Distant tile center:(59, 95)
# Sampling image Industrial_1438.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(93, 35)
#     Neighbor tile center:(79, 79)
# Sampling image Industrial_1527.tif from dir
#     Saving distant tile #2
#     Distant tile center:(55, 32)
# Sampling image Industrial_1565.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(76, 45)
#     Neighbor tile center:(80, 33)
# Sampling image Industrial_1626.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(79, 38)
#     Neighbor tile center:(47, 79)
# Sampling image Industrial_1655.tif from dir
#     Saving distant tile #7
#     Distant tile center:(63, 67)
# Sampling image Industrial_1716.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(64, 75)
#     Neighbor tile center:(55, 76)
# Sampling image Industrial_1727.tif from dir
#     Saving distant tile #5
#     Distant tile center:(57, 47)
# Sampling image Industrial_1758.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(64, 39)
#     Neighbor tile center:(74, 48)
# Sampling image Industrial_1902.tif from dir
#     Saving distant tile #4
#     Distant tile center:(41, 88)
# Sampling image Industrial_1915.tif from dir
#     Saving distant tile #6
#     Distant tile center:(93, 57)
# Sampling image Industrial_1994.tif from dir
#     Saving distant tile #1
#     Distant tile center:(37, 80)
# Sampling image Industrial_2054.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(39, 51)
#     Neighbor tile center:(72, 57)
# Sampling image Industrial_2261.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(47, 90)
#     Neighbor tile center:(85, 80)
# Sampling image Industrial_259.tif from dir
#     Saving distant tile #0
#     Distant tile center:(62, 51)
# Sampling image Industrial_385.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(63, 87)
#     Neighbor tile center:(63, 68)
# Sampling image Industrial_517.tif from dir
#     Saving distant tile #3
#     Distant tile center:(33, 43)
# Sampling image Industrial_654.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(38, 49)
#     Neighbor tile center:(56, 78)
# Sampling image Industrial_981.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(89, 36)
#     Neighbor tile center:(46, 39)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['River_2354.tif' 'River_2243.tif']
#  ['River_1693.tif' 'River_51.tif']
#  ['River_721.tif' 'River_732.tif']
#  ['River_1116.tif' 'River_1693.tif']
#  ['River_1167.tif' 'River_2171.tif']]
# Sampling image River_1116.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(76, 87)
#     Neighbor tile center:(67, 42)
# Sampling image River_1167.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(47, 35)
#     Neighbor tile center:(55, 35)
# Sampling image River_1464.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(72, 59)
#     Neighbor tile center:(34, 78)
# Sampling image River_1693.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(50, 84)
#     Neighbor tile center:(47, 54)
#     Saving distant tile #3
#     Distant tile center:(88, 35)
# Sampling image River_1712.tif from dir
#     Saving distant tile #5
#     Distant tile center:(46, 71)
# Sampling image River_1772.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(43, 78)
#     Neighbor tile center:(36, 95)
# Sampling image River_1807.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(56, 55)
#     Neighbor tile center:(85, 65)
# Sampling image River_1870.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(80, 78)
#     Neighbor tile center:(73, 75)
# Sampling image River_2125.tif from dir
#     Saving distant tile #6
#     Distant tile center:(47, 46)
# Sampling image River_2171.tif from dir
#     Saving distant tile #4
#     Distant tile center:(72, 41)
# Sampling image River_2188.tif from dir
#     Saving distant tile #8
#     Distant tile center:(82, 79)
# Sampling image River_2194.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(52, 58)
#     Neighbor tile center:(63, 53)
# Sampling image River_2243.tif from dir
#     Saving distant tile #0
#     Distant tile center:(72, 83)
# Sampling image River_2354.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(55, 45)
#     Neighbor tile center:(68, 66)
# Sampling image River_51.tif from dir
#     Saving distant tile #1
#     Distant tile center:(62, 79)
# Sampling image River_721.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(85, 49)
#     Neighbor tile center:(46, 73)
# Sampling image River_732.tif from dir
#     Saving distant tile #2
#     Distant tile center:(95, 48)
# Sampling image River_863.tif from dir
#     Saving distant tile #9
#     Distant tile center:(85, 92)
# Sampling image River_94.tif from dir
#     Saving distant tile #7
#     Distant tile center:(95, 95)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['Pasture_359.tif' 'Pasture_1430.tif']
#  ['Pasture_1078.tif' 'Pasture_1439.tif']
#  ['Pasture_1652.tif' 'Pasture_861.tif']
#  ['Pasture_558.tif' 'Pasture_1185.tif']
#  ['Pasture_1665.tif' 'Pasture_456.tif']]
# Sampling image Pasture_1078.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(79, 54)
#     Neighbor tile center:(68, 92)
# Sampling image Pasture_1185.tif from dir
#     Saving distant tile #3
#     Distant tile center:(70, 68)
# Sampling image Pasture_1372.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(75, 64)
#     Neighbor tile center:(75, 90)
# Sampling image Pasture_1430.tif from dir
#     Saving distant tile #0
#     Distant tile center:(70, 54)
# Sampling image Pasture_1439.tif from dir
#     Saving distant tile #1
#     Distant tile center:(77, 93)
# Sampling image Pasture_145.tif from dir
#     Saving distant tile #8
#     Distant tile center:(47, 94)
# Sampling image Pasture_1510.tif from dir
#     Saving distant tile #9
#     Distant tile center:(50, 93)
# Sampling image Pasture_1623.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(84, 33)
#     Neighbor tile center:(82, 80)
# Sampling image Pasture_1652.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(41, 38)
#     Neighbor tile center:(75, 92)
# Sampling image Pasture_1665.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(38, 59)
#     Neighbor tile center:(40, 39)
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(51, 94)
#     Neighbor tile center:(59, 76)
# Sampling image Pasture_1781.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(93, 77)
#     Neighbor tile center:(89, 43)
# Sampling image Pasture_1808.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(33, 67)
#     Neighbor tile center:(78, 39)
# Sampling image Pasture_1856.tif from dir
#     Saving distant tile #6
#     Distant tile center:(45, 35)
# Sampling image Pasture_359.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(65, 81)
#     Neighbor tile center:(40, 73)
# Sampling image Pasture_456.tif from dir
#     Saving distant tile #4
#     Distant tile center:(55, 33)
# Sampling image Pasture_558.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(95, 45)
#     Neighbor tile center:(61, 64)
# Sampling image Pasture_596.tif from dir
#     Saving distant tile #5
#     Distant tile center:(85, 37)
# Sampling image Pasture_861.tif from dir
#     Saving distant tile #2
#     Distant tile center:(48, 73)
# Sampling image Pasture_889.tif from dir
#     Saving distant tile #7
#     Distant tile center:(55, 79)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['Residential_1906.tif' 'Residential_1584.tif']
#  ['Residential_1842.tif' 'Residential_226.tif']
#  ['Residential_18.tif' 'Residential_6.tif']
#  ['Residential_2807.tif' 'Residential_314.tif']
#  ['Residential_21.tif' 'Residential_714.tif']]
# Sampling image Residential_1235.tif from dir
#     Saving distant tile #5
#     Distant tile center:(68, 76)
# Sampling image Residential_1453.tif from dir
#     Saving distant tile #8
#     Distant tile center:(46, 61)
# Sampling image Residential_1584.tif from dir
#     Saving distant tile #0
#     Distant tile center:(92, 40)
# Sampling image Residential_1601.tif from dir
#     Saving distant tile #7
#     Distant tile center:(45, 49)
# Sampling image Residential_18.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(47, 51)
#     Neighbor tile center:(87, 71)
# Sampling image Residential_1842.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(47, 67)
#     Neighbor tile center:(80, 84)
# Sampling image Residential_1906.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(61, 78)
#     Neighbor tile center:(58, 72)
# Sampling image Residential_1975.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(81, 69)
#     Neighbor tile center:(67, 92)
# Sampling image Residential_21.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(74, 89)
#     Neighbor tile center:(63, 94)
# Sampling image Residential_226.tif from dir
#     Saving distant tile #1
#     Distant tile center:(42, 81)
# Sampling image Residential_2807.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(46, 87)
#     Neighbor tile center:(43, 63)
# Sampling image Residential_2906.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(58, 38)
#     Neighbor tile center:(55, 80)
# Sampling image Residential_314.tif from dir
#     Saving distant tile #3
#     Distant tile center:(83, 91)
# Sampling image Residential_475.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(70, 38)
#     Neighbor tile center:(79, 52)
# Sampling image Residential_6.tif from dir
#     Saving distant tile #2
#     Distant tile center:(85, 66)
# Sampling image Residential_659.tif from dir
#     Saving distant tile #9
#     Distant tile center:(73, 39)
# Sampling image Residential_712.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(42, 39)
#     Neighbor tile center:(74, 36)
# Sampling image Residential_714.tif from dir
#     Saving distant tile #4
#     Distant tile center:(73, 33)
# Sampling image Residential_724.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(54, 85)
#     Neighbor tile center:(91, 90)
# Sampling image Residential_990.tif from dir
#     Saving distant tile #6
#     Distant tile center:(44, 42)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['PermanentCrop_1919.tif' 'PermanentCrop_37.tif']
#  ['PermanentCrop_2203.tif' 'PermanentCrop_689.tif']
#  ['PermanentCrop_1898.tif' 'PermanentCrop_861.tif']
#  ['PermanentCrop_2193.tif' 'PermanentCrop_1376.tif']
#  ['PermanentCrop_1851.tif' 'PermanentCrop_227.tif']]
# Sampling image PermanentCrop_1376.tif from dir
#     Saving distant tile #3
#     Distant tile center:(56, 37)
# Sampling image PermanentCrop_1672.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(82, 79)
#     Neighbor tile center:(36, 66)
# Sampling image PermanentCrop_1697.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(33, 64)
#     Neighbor tile center:(71, 47)
# Sampling image PermanentCrop_1851.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(49, 35)
#     Neighbor tile center:(70, 72)
# Sampling image PermanentCrop_186.tif from dir
#     Saving distant tile #8
#     Distant tile center:(60, 71)
# Sampling image PermanentCrop_1898.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(63, 33)
#     Neighbor tile center:(68, 49)
# Sampling image PermanentCrop_1919.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(49, 54)
#     Neighbor tile center:(77, 38)
# Sampling image PermanentCrop_2064.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(89, 95)
#     Neighbor tile center:(82, 46)
# Sampling image PermanentCrop_2176.tif from dir
#     Saving distant tile #5
#     Distant tile center:(40, 41)
# Sampling image PermanentCrop_2193.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(36, 77)
#     Neighbor tile center:(59, 75)
# Sampling image PermanentCrop_2203.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(70, 55)
#     Neighbor tile center:(91, 75)
# Sampling image PermanentCrop_2208.tif from dir
#     Saving distant tile #6
#     Distant tile center:(65, 35)
# Sampling image PermanentCrop_227.tif from dir
#     Saving distant tile #4
#     Distant tile center:(90, 48)
# Sampling image PermanentCrop_2302.tif from dir
#     Saving distant tile #9
#     Distant tile center:(34, 46)
# Sampling image PermanentCrop_300.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(57, 32)
#     Neighbor tile center:(80, 43)
# Sampling image PermanentCrop_37.tif from dir
#     Saving distant tile #0
#     Distant tile center:(91, 39)
# Sampling image PermanentCrop_381.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(86, 49)
#     Neighbor tile center:(80, 35)
# Sampling image PermanentCrop_689.tif from dir
#     Saving distant tile #1
#     Distant tile center:(82, 58)
# Sampling image PermanentCrop_861.tif from dir
#     Saving distant tile #2
#     Distant tile center:(80, 36)
# Sampling image PermanentCrop_869.tif from dir
#     Saving distant tile #7
#     Distant tile center:(42, 90)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['Forest_1562.tif' 'Forest_439.tif']
#  ['Forest_397.tif' 'Forest_964.tif']
#  ['Forest_1180.tif' 'Forest_1769.tif']
#  ['Forest_1270.tif' 'Forest_2915.tif']
#  ['Forest_778.tif' 'Forest_2072.tif']]
# Sampling image Forest_1180.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(93, 75)
#     Neighbor tile center:(66, 72)
# Sampling image Forest_1270.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(93, 54)
#     Neighbor tile center:(39, 88)
# Sampling image Forest_1429.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(48, 95)
#     Neighbor tile center:(89, 63)
# Sampling image Forest_1508.tif from dir
#     Saving distant tile #5
#     Distant tile center:(61, 42)
# Sampling image Forest_1525.tif from dir
#     Saving distant tile #8
#     Distant tile center:(64, 91)
# Sampling image Forest_1562.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(71, 69)
#     Neighbor tile center:(45, 87)
# Sampling image Forest_163.tif from dir
#     Saving distant tile #6
#     Distant tile center:(40, 88)
# Sampling image Forest_1769.tif from dir
#     Saving distant tile #2
#     Distant tile center:(55, 69)
# Sampling image Forest_1921.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(35, 46)
#     Neighbor tile center:(91, 46)
# Sampling image Forest_1930.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(82, 90)
#     Neighbor tile center:(74, 40)
# Sampling image Forest_2011.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(52, 72)
#     Neighbor tile center:(84, 66)
# Sampling image Forest_2051.tif from dir
#     Saving distant tile #7
#     Distant tile center:(53, 85)
# Sampling image Forest_2072.tif from dir
#     Saving distant tile #4
#     Distant tile center:(36, 67)
# Sampling image Forest_2915.tif from dir
#     Saving distant tile #3
#     Distant tile center:(77, 55)
# Sampling image Forest_374.tif from dir
#     Saving distant tile #9
#     Distant tile center:(73, 41)
# Sampling image Forest_397.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(59, 43)
#     Neighbor tile center:(89, 52)
# Sampling image Forest_429.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(55, 57)
#     Neighbor tile center:(85, 66)
# Sampling image Forest_439.tif from dir
#     Saving distant tile #0
#     Distant tile center:(55, 77)
# Sampling image Forest_778.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(53, 94)
#     Neighbor tile center:(95, 50)
# Sampling image Forest_964.tif from dir
#     Saving distant tile #1
#     Distant tile center:(83, 81)
# Current dir: /storage/EuroSATallBands/SeaLake
# [['SeaLake_1219.tif' 'Jakarta_000222.tif']
#  ['SeaLake_1511.tif' 'SeaLake_1625.tif']
#  ['SeaLake_826.tif' 'SeaLake_1400.tif']
#  ['SeaLake_800.tif' 'Jakarta_000045.tif']
#  ['SeaLake_2738.tif' 'SeaLake_414.tif']]
# Sampling image Bombay_000024.tif from dir
#     Saving distant tile #8
#     Distant tile center:(85, 75)
# Sampling image Jakarta_000045.tif from dir
#     Saving distant tile #3
#     Distant tile center:(60, 68)
# Sampling image Jakarta_000222.tif from dir
#     Saving distant tile #0
#     Distant tile center:(55, 78)
# Sampling image SeaLake_1187.tif from dir
#     Saving anchor and neighbor tile #8
#     Anchor tile center:(56, 69)
#     Neighbor tile center:(38, 71)
# Sampling image SeaLake_1219.tif from dir
#     Saving anchor and neighbor tile #0
#     Anchor tile center:(58, 46)
#     Neighbor tile center:(74, 39)
# Sampling image SeaLake_130.tif from dir
#     Saving anchor and neighbor tile #6
#     Anchor tile center:(42, 57)
#     Neighbor tile center:(58, 83)
# Sampling image SeaLake_1400.tif from dir
#     Saving distant tile #2
#     Distant tile center:(91, 43)
# Sampling image SeaLake_143.tif from dir
#     Saving anchor and neighbor tile #9
#     Anchor tile center:(49, 50)
#     Neighbor tile center:(95, 76)
# Sampling image SeaLake_1511.tif from dir
#     Saving anchor and neighbor tile #1
#     Anchor tile center:(35, 63)
#     Neighbor tile center:(72, 58)
# Sampling image SeaLake_1625.tif from dir
#     Saving distant tile #1
#     Distant tile center:(75, 63)
# Sampling image SeaLake_1935.tif from dir
#     Saving anchor and neighbor tile #5
#     Anchor tile center:(70, 65)
#     Neighbor tile center:(90, 89)
# Sampling image SeaLake_1948.tif from dir
#     Saving anchor and neighbor tile #7
#     Anchor tile center:(38, 65)
#     Neighbor tile center:(81, 71)
# Sampling image SeaLake_1968.tif from dir
#     Saving distant tile #7
#     Distant tile center:(33, 78)
# Sampling image SeaLake_2738.tif from dir
#     Saving anchor and neighbor tile #4
#     Anchor tile center:(47, 34)
#     Neighbor tile center:(34, 87)
# Sampling image SeaLake_2755.tif from dir
#     Saving distant tile #9
#     Distant tile center:(64, 61)
# Sampling image SeaLake_2940.tif from dir
#     Saving distant tile #5
#     Distant tile center:(39, 75)
# Sampling image SeaLake_414.tif from dir
#     Saving distant tile #4
#     Distant tile center:(68, 39)
# Sampling image SeaLake_681.tif from dir
#     Saving distant tile #6
#     Distant tile center:(57, 90)
# Sampling image SeaLake_800.tif from dir
#     Saving anchor and neighbor tile #3
#     Anchor tile center:(39, 49)
#     Neighbor tile center:(42, 57)
# Sampling image SeaLake_826.tif from dir
#     Saving anchor and neighbor tile #2
#     Anchor tile center:(56, 68)
#     Neighbor tile center:(72, 77)

# %% [markdown]
# # Train

# %% [markdown]
# ## Setup data

# %%
# Environment stuff
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
cuda = torch.cuda.is_available()

# Change these arguments to match your directory and desired parameters
img_type = 'naip'
tile_dir = '../data/triplets/'
bands = 12
augment = True
batch_size = 50
shuffle = True
num_workers = 4
n_triplets = 100000

dataloader = triplet_dataloader(img_type, tile_dir, bands=bands, augment=augment,
                                batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, 
                                n_triplets=n_triplets, pairs_only=True)
print('Dataloader set up complete.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Environment stuff
#       2 os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# ----> 3 cuda = torch.cuda.is_available()
#       5 # Change these arguments to match your directory and desired parameters
#       6 img_type = 'naip'
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ## Setup tilenet

# %%
in_channels = bands
z_dim = 512

TileNet = make_tilenet(in_channels=in_channels, z_dim=z_dim)
TileNet.train()
if cuda: TileNet.cuda()
print('TileNet set up complete.')

lr = 1e-3
optimizer = optim.Adam(TileNet.parameters(), lr=lr, betas=(0.5, 0.999))

# %% [markdown]
# # Train model

# %%
epochs = 50
margin = 10
l2 = 0.01
print_every = 10000
save_models = True

model_dir = '../models/'
if not os.path.exists(model_dir): os.makedirs(model_dir)

t0 = time()
with open(results_fn, 'w') as file:

    print('Begin training.................')
    for epoch in range(0, epochs):
        (avg_loss, avg_l_n, avg_l_d, avg_l_nd) = train_triplet_epoch(
            TileNet, cuda, dataloader, optimizer, epoch+1, margin=margin, l2=l2,
            print_every=print_every, t0=t0)

# Save model after last epoch
if save_models:
    model_fn = os.path.join(model_dir, 'TileNet_epoch50.ckpt')
    torch.save(TileNet.state_dict(), model_fn)
